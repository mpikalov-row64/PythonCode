# %%
import pandas as pd
import random
import time
import uuid
from datetime import datetime, timedelta
import numpy as np
from kafka import KafkaProducer
import json

# =========================================================
# CONFIGURATION

INPUT_CSV = r"C:\Users\mikha\OneDrive\Documents\Demos\AI Observability\OpenAI_MockResponses.csv"
NUM_MODELS = [
    "gpt-4.1",
    "gpt-4o-mini",
    "gpt-3.5-turbo",
    "llama2-13b",
    "mistral-7b-instruct"
]

LATENCY_RANGE = (0.1, 1.5)
INPUT_TOKENS_RANGE = (10, 80)
OUTPUT_TOKENS_RANGE = (30, 200)
READABILITY_RANGE = (30, 90)
COMPLEXITY_RANGE = (1, 10)
RANDOM_SEED = 42
random.seed(RANDOM_SEED)

NORMAL_CENTER = [0.5, 0.5]
ATTACK_CENTER = [0.9, 0.9]

MAX_MESSAGES = 100_000

# Time range for timestamps: last 3 months
END_DATE = datetime.now()
START_DATE = END_DATE - timedelta(days=90)

# Kafka producer
producer = KafkaProducer(
    bootstrap_servers="localhost:9092",
    value_serializer=lambda v: json.dumps(v, default=str).encode("utf-8")  # datetime -> str
)
TOPIC_KAFKA = "llmevents"

# Agent Steps Mapping (Mermaid Graph)
AGENT_STEPS = [
    "step_3", "step_5a", "step_5b", "step_6", "step_7", "step_8a", "step_8b"
]
STEP_NAMES = {
    "step_3": "Safety Filter (Guardrail)",
    "step_5a": "Knowledge Retrieval",
    "step_5b": "Tools / External API",
    "step_6": "LLM Inference",
    "step_7": "Hallucination Check",
    "step_8a": "Retry Request",
    "step_8b": "User Response"
}

# =========================================================
# HELPER FUNCTIONS

def mock_metrics(model_output):
    input_tokens = random.randint(*INPUT_TOKENS_RANGE)
    output_tokens = random.randint(*OUTPUT_TOKENS_RANGE)
    total_tokens = input_tokens + output_tokens
    latency = round(random.uniform(*LATENCY_RANGE), 3)
    
    num_sentences = len(model_output.split("."))
    num_words = len(model_output.split())
    
    return {
        "input_tokens": input_tokens,
        "output_tokens": output_tokens,
        "total_tokens": total_tokens,
        "latency_sec": latency,
        "estimated_cost_usd": round((input_tokens/1000)*0.0002 + (output_tokens/1000)*0.0008,6),
        "num_sentences": num_sentences,
        "num_words": num_words,
        "num_special_tokens": random.randint(0,5),
        "prompt_complexity_score": random.randint(*COMPLEXITY_RANGE),
        "output_readability_score": random.randint(*READABILITY_RANGE),
        "hallucination_score": round(random.uniform(0,1),3),
        "repetition_score": round(random.uniform(0,1),3),
        "sentiment_score": round(random.uniform(-1,1),3),
        "response_variation_score": round(random.uniform(0,1),3),
        "toxicity_score": round(random.uniform(0,1),3),
        "model_version": f"v{random.randint(1,3)}.{random.randint(0,9)}.{random.randint(0,9)}",
        "num_edits_required": random.randint(0,5)
    }

def generate_embeddings(event_type):
    if event_type == "jailbreak_attempt":
        x, y = np.random.normal(ATTACK_CENTER, 0.05, 2)
    else:
        x, y = np.random.normal(NORMAL_CENTER, 0.2, 2)
    return float(np.clip(x,0,1)), float(np.clip(y,0,1))

def random_datetime(start, end):
    """Generate a random datetime between start and end"""
    delta = end - start
    random_seconds = random.randint(0, int(delta.total_seconds()))
    return start + timedelta(seconds=random_seconds)

# =========================================================
# LOAD INPUT CSV

df_input = pd.read_csv(INPUT_CSV)
print(f"Loaded {len(df_input)} rows from {INPUT_CSV}")

# =========================================================
# STREAM EVENTS TO KAFKA (100k messages)

message_count = 0

while message_count < MAX_MESSAGES:
    for idx, row_input in df_input.iterrows():
        for model in NUM_MODELS:
            if message_count >= MAX_MESSAGES:
                print(f"✅ Reached {MAX_MESSAGES} messages. Stopping stream.")
                break
            
            seed_val = RANDOM_SEED + idx + hash(model) % 10000
            random.seed(seed_val)
            
            # Event type
            event_type = "jailbreak_attempt" if random.random() > 0.95 else "llm_generation"
            
            # Assign agent step
            if event_type == "jailbreak_attempt":
                agent_step_id = "step_4a"
                agent_step_name = "Blocked Request"
            else:
                agent_step_id = random.choice(AGENT_STEPS)
                agent_step_name = STEP_NAMES.get(agent_step_id, agent_step_id)
            
            embedding_x, embedding_y = generate_embeddings(event_type)
            metrics = mock_metrics(row_input["mock_response"])
            
            # Realistic timestamp
            generation_dt = random_datetime(START_DATE, END_DATE)
            
            # Build record
            record = row_input.to_dict()
            record.update({
                "trace_id": str(uuid.uuid5(uuid.NAMESPACE_DNS, f"{idx}-{model}")),
                "model": model,
                "event_type": event_type,
                "embedding_x": embedding_x,
                "embedding_y": embedding_y,
                "generation_timestamp": generation_dt,
                "agent_step_id": agent_step_id,
                "agent_step_name": agent_step_name
            })
            record.update(metrics)
            
            # Send to Kafka
            producer.send(TOPIC_KAFKA, record)
            
            message_count += 1
            if message_count % 1000 == 0:
                print(f"[{message_count}] messages sent...")
            
            # Small sleep to simulate near-real-time streaming
            time.sleep(0.001)
# Out:
# Loaded 110 rows from C:\Users\mikha\OneDrive\Documents\Demos\AI Observability\OpenAI_MockResponses.csv
# {'topic': 'cloud computing', 'topic_category': 'Technology', 'user_prompt': 'How can I optimize my cloud infrastructure costs?', 'mock_response': 'You can optimize cloud costs by reviewing resource utilization, using reserved instances, and automating scaling based on demand.', 'trace_id': 'f62e4d22-916f-5155-85b3-b4d96e924c5f', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.526335159226646, 'embedding_y': 0.4532222142600074, 'generation_timestamp': 1765484065.2660203, 'input_tokens': 58, 'output_tokens': 181, 'total_tokens': 239, 'latency_sec': 0.747, 'estimated_cost_usd': 0.000156, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 0, 'prompt_complexity_score': 10, 'output_readability_score': 35, 'hallucination_score': 0.422, 'repetition_score': 0.509, 'sentiment_score': 0.783, 'response_variation_score': 0.951, 'toxicity_score': 0.588, 'model_version': 'v3.7.6', 'num_edits_required': 0}
# {'topic': 'cloud computing', 'topic_category': 'Technology', 'user_prompt': 'How can I optimize my cloud infrastructure costs?', 'mock_response': 'You can optimize cloud costs by reviewing resource utilization, using reserved instances, and automating scaling based on demand.', 'trace_id': '514b5188-0d5f-55e7-ae54-534804e1e3a1', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.5034092060715287, 'embedding_y': 0.43911485247242005, 'generation_timestamp': 1765484065.383731, 'input_tokens': 63, 'output_tokens': 43, 'total_tokens': 106, 'latency_sec': 1.188, 'estimated_cost_usd': 4.7e-05, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 0, 'prompt_complexity_score': 3, 'output_readability_score': 64, 'hallucination_score': 0.112, 'repetition_score': 0.734, 'sentiment_score': -0.141, 'response_variation_score': 0.106, 'toxicity_score': 0.084, 'model_version': 'v2.5.1', 'num_edits_required': 4}
# {'topic': 'cloud computing', 'topic_category': 'Technology', 'user_prompt': 'How can I optimize my cloud infrastructure costs?', 'mock_response': 'You can optimize cloud costs by reviewing resource utilization, using reserved instances, and automating scaling based on demand.', 'trace_id': '173dc1f4-d9cf-5bf0-9d8d-3780adbdff8c', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.7300699911166376, 'embedding_y': 0.7746718403190838, 'generation_timestamp': 1765484065.3858142, 'input_tokens': 53, 'output_tokens': 148, 'total_tokens': 201, 'latency_sec': 1.24, 'estimated_cost_usd': 0.000129, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 4, 'prompt_complexity_score': 9, 'output_readability_score': 37, 'hallucination_score': 0.255, 'repetition_score': 0.251, 'sentiment_score': -0.294, 'response_variation_score': 0.955, 'toxicity_score': 0.477, 'model_version': 'v2.4.6', 'num_edits_required': 4}
# {'topic': 'cloud computing', 'topic_category': 'Technology', 'user_prompt': 'How can I optimize my cloud infrastructure costs?', 'mock_response': 'You can optimize cloud costs by reviewing resource utilization, using reserved instances, and automating scaling based on demand.', 'trace_id': '742be5e0-56dc-5648-8897-a60385bf029e', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.7825556067350314, 'embedding_y': 0.42370484751548065, 'generation_timestamp': 1765484065.3879735, 'input_tokens': 48, 'output_tokens': 75, 'total_tokens': 123, 'latency_sec': 1.023, 'estimated_cost_usd': 7e-05, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 4, 'prompt_complexity_score': 7, 'output_readability_score': 40, 'hallucination_score': 0.221, 'repetition_score': 0.242, 'sentiment_score': -0.617, 'response_variation_score': 0.753, 'toxicity_score': 0.124, 'model_version': 'v3.2.0', 'num_edits_required': 5}
# {'topic': 'cloud computing', 'topic_category': 'Technology', 'user_prompt': 'How can I optimize my cloud infrastructure costs?', 'mock_response': 'You can optimize cloud costs by reviewing resource utilization, using reserved instances, and automating scaling based on demand.', 'trace_id': '4862e868-e287-5bcb-92ed-620d388e7031', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.8411047374830319, 'embedding_y': 0.4662338326207537, 'generation_timestamp': 1765484065.3896017, 'input_tokens': 75, 'output_tokens': 117, 'total_tokens': 192, 'latency_sec': 0.951, 'estimated_cost_usd': 0.000109, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 4, 'prompt_complexity_score': 6, 'output_readability_score': 69, 'hallucination_score': 0.588, 'repetition_score': 0.173, 'sentiment_score': 0.786, 'response_variation_score': 0.115, 'toxicity_score': 0.912, 'model_version': 'v1.5.5', 'num_edits_required': 2}
# {'topic': 'stock analysis', 'topic_category': 'Finance', 'user_prompt': 'What are the key metrics to evaluate a stock?', 'mock_response': 'Important metrics include P/E ratio, EPS growth, dividend yield, and debt-to-equity ratio.', 'trace_id': 'f69bd8dc-766d-566f-bc69-ec66065e4305', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.5976178165676514, 'embedding_y': 0.5579579520238639, 'generation_timestamp': 1765484065.3912003, 'input_tokens': 23, 'output_tokens': 147, 'total_tokens': 170, 'latency_sec': 1.125, 'estimated_cost_usd': 0.000122, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 0, 'prompt_complexity_score': 10, 'output_readability_score': 43, 'hallucination_score': 0.849, 'repetition_score': 0.044, 'sentiment_score': 0.462, 'response_variation_score': 0.429, 'toxicity_score': 0.172, 'model_version': 'v2.3.8', 'num_edits_required': 2}
# {'topic': 'stock analysis', 'topic_category': 'Finance', 'user_prompt': 'What are the key metrics to evaluate a stock?', 'mock_response': 'Important metrics include P/E ratio, EPS growth, dividend yield, and debt-to-equity ratio.', 'trace_id': '798ab045-103e-5562-85cf-4c57e0b50049', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.3741257110110029, 'embedding_y': 0.5331699093123311, 'generation_timestamp': 1765484065.3930194, 'input_tokens': 27, 'output_tokens': 147, 'total_tokens': 174, 'latency_sec': 1.167, 'estimated_cost_usd': 0.000123, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 1, 'prompt_complexity_score': 7, 'output_readability_score': 90, 'hallucination_score': 0.834, 'repetition_score': 0.075, 'sentiment_score': -0.608, 'response_variation_score': 0.22, 'toxicity_score': 0.343, 'model_version': 'v2.3.9', 'num_edits_required': 3}
# {'topic': 'stock analysis', 'topic_category': 'Finance', 'user_prompt': 'What are the key metrics to evaluate a stock?', 'mock_response': 'Important metrics include P/E ratio, EPS growth, dividend yield, and debt-to-equity ratio.', 'trace_id': 'dbf6f930-7702-5e71-8d31-44eb92e87bb1', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.4546162504021972, 'embedding_y': 0.46142838767493194, 'generation_timestamp': 1765484065.3945012, 'input_tokens': 51, 'output_tokens': 138, 'total_tokens': 189, 'latency_sec': 0.529, 'estimated_cost_usd': 0.000121, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 2, 'prompt_complexity_score': 9, 'output_readability_score': 45, 'hallucination_score': 0.648, 'repetition_score': 0.608, 'sentiment_score': -0.078, 'response_variation_score': 0.469, 'toxicity_score': 0.406, 'model_version': 'v3.7.7', 'num_edits_required': 5}
# {'topic': 'stock analysis', 'topic_category': 'Finance', 'user_prompt': 'What are the key metrics to evaluate a stock?', 'mock_response': 'Important metrics include P/E ratio, EPS growth, dividend yield, and debt-to-equity ratio.', 'trace_id': 'd2b1b208-2c5b-52d0-8dc9-71c9b47a5068', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.781170455735031, 'embedding_y': 0.5182321303824362, 'generation_timestamp': 1765484065.3960307, 'input_tokens': 78, 'output_tokens': 84, 'total_tokens': 162, 'latency_sec': 1.004, 'estimated_cost_usd': 8.3e-05, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 5, 'prompt_complexity_score': 7, 'output_readability_score': 42, 'hallucination_score': 0.331, 'repetition_score': 0.424, 'sentiment_score': 0.587, 'response_variation_score': 0.403, 'toxicity_score': 0.609, 'model_version': 'v1.1.2', 'num_edits_required': 3}
# {'topic': 'stock analysis', 'topic_category': 'Finance', 'user_prompt': 'What are the key metrics to evaluate a stock?', 'mock_response': 'Important metrics include P/E ratio, EPS growth, dividend yield, and debt-to-equity ratio.', 'trace_id': '7babf413-4878-5425-b6db-13b75b1a525c', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.615956982190295, 'embedding_y': 0.4097606141943321, 'generation_timestamp': 1765484065.397813, 'input_tokens': 49, 'output_tokens': 183, 'total_tokens': 232, 'latency_sec': 0.665, 'estimated_cost_usd': 0.000156, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 4, 'prompt_complexity_score': 4, 'output_readability_score': 85, 'hallucination_score': 0.083, 'repetition_score': 0.623, 'sentiment_score': 0.337, 'response_variation_score': 0.564, 'toxicity_score': 0.619, 'model_version': 'v1.5.6', 'num_edits_required': 0}
# {'topic': 'project management', 'topic_category': 'Business', 'user_prompt': 'Can you suggest tools for tracking project progress?', 'mock_response': 'Popular tools include Jira, Asana, and Trello, which allow task assignment, progress tracking, and collaboration.', 'trace_id': 'a6cfc6a1-3feb-5fcb-90d8-29e7ac614562', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.5831582782953135, 'embedding_y': 0.6711712712270648, 'generation_timestamp': 1765484065.3997262, 'input_tokens': 73, 'output_tokens': 127, 'total_tokens': 200, 'latency_sec': 0.933, 'estimated_cost_usd': 0.000116, 'num_sentences': 2, 'num_words': 15, 'num_special_tokens': 2, 'prompt_complexity_score': 9, 'output_readability_score': 75, 'hallucination_score': 0.132, 'repetition_score': 0.478, 'sentiment_score': -0.963, 'response_variation_score': 0.223, 'toxicity_score': 0.912, 'model_version': 'v1.1.6', 'num_edits_required': 4}
# {'topic': 'project management', 'topic_category': 'Business', 'user_prompt': 'Can you suggest tools for tracking project progress?', 'mock_response': 'Popular tools include Jira, Asana, and Trello, which allow task assignment, progress tracking, and collaboration.', 'trace_id': '209d450b-56cd-5d9e-9771-d4d0d2971c7e', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.6020008788051403, 'embedding_y': 0.7905834766305286, 'generation_timestamp': 1765484065.401115, 'input_tokens': 61, 'output_tokens': 69, 'total_tokens': 130, 'latency_sec': 0.197, 'estimated_cost_usd': 6.7e-05, 'num_sentences': 2, 'num_words': 15, 'num_special_tokens': 5, 'prompt_complexity_score': 4, 'output_readability_score': 51, 'hallucination_score': 0.171, 'repetition_score': 0.132, 'sentiment_score': -0.498, 'response_variation_score': 0.187, 'toxicity_score': 0.517, 'model_version': 'v3.8.5', 'num_edits_required': 1}
# {'topic': 'project management', 'topic_category': 'Business', 'user_prompt': 'Can you suggest tools for tracking project progress?', 'mock_response': 'Popular tools include Jira, Asana, and Trello, which allow task assignment, progress tracking, and collaboration.', 'trace_id': '18bc972a-1c65-5e3c-8f6f-6b6ed22f5622', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.4139588233442267, 'embedding_y': 0.4707759667683685, 'generation_timestamp': 1765484065.4030757, 'input_tokens': 73, 'output_tokens': 148, 'total_tokens': 221, 'latency_sec': 0.536, 'estimated_cost_usd': 0.000133, 'num_sentences': 2, 'num_words': 15, 'num_special_tokens': 2, 'prompt_complexity_score': 7, 'output_readability_score': 35, 'hallucination_score': 0.252, 'repetition_score': 0.732, 'sentiment_score': 0.13, 'response_variation_score': 0.616, 'toxicity_score': 0.567, 'model_version': 'v2.5.3', 'num_edits_required': 3}
# {'topic': 'project management', 'topic_category': 'Business', 'user_prompt': 'Can you suggest tools for tracking project progress?', 'mock_response': 'Popular tools include Jira, Asana, and Trello, which allow task assignment, progress tracking, and collaboration.', 'trace_id': 'd9e7ffeb-d25f-5dca-92fc-34c2f23cf8be', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.5621340366491481, 'embedding_y': 0.4060107072845739, 'generation_timestamp': 1765484065.404619, 'input_tokens': 44, 'output_tokens': 125, 'total_tokens': 169, 'latency_sec': 0.106, 'estimated_cost_usd': 0.000109, 'num_sentences': 2, 'num_words': 15, 'num_special_tokens': 0, 'prompt_complexity_score': 7, 'output_readability_score': 75, 'hallucination_score': 0.164, 'repetition_score': 0.764, 'sentiment_score': 0.423, 'response_variation_score': 0.629, 'toxicity_score': 0.966, 'model_version': 'v3.8.4', 'num_edits_required': 0}
# {'topic': 'project management', 'topic_category': 'Business', 'user_prompt': 'Can you suggest tools for tracking project progress?', 'mock_response': 'Popular tools include Jira, Asana, and Trello, which allow task assignment, progress tracking, and collaboration.', 'trace_id': 'b7adb57b-c914-5df6-8d58-9c566334707e', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.382322869796395, 'embedding_y': 0.41992190077327085, 'generation_timestamp': 1765484065.4069161, 'input_tokens': 22, 'output_tokens': 198, 'total_tokens': 220, 'latency_sec': 0.109, 'estimated_cost_usd': 0.000163, 'num_sentences': 2, 'num_words': 15, 'num_special_tokens': 4, 'prompt_complexity_score': 7, 'output_readability_score': 88, 'hallucination_score': 0.032, 'repetition_score': 0.914, 'sentiment_score': 0.594, 'response_variation_score': 0.605, 'toxicity_score': 0.144, 'model_version': 'v2.4.9', 'num_edits_required': 3}
# {'topic': 'cybersecurity', 'topic_category': 'Technology', 'user_prompt': 'How do I secure our internal network from threats?', 'mock_response': 'Implement firewalls, regularly update software, use strong authentication, and conduct employee security training.', 'trace_id': '9f586c5d-c06d-5ca8-8a7c-e21c408e8a40', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.652943684466406, 'embedding_y': 0.6011641364285353, 'generation_timestamp': 1765484065.4088128, 'input_tokens': 58, 'output_tokens': 100, 'total_tokens': 158, 'latency_sec': 1.169, 'estimated_cost_usd': 9.2e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 3, 'prompt_complexity_score': 10, 'output_readability_score': 68, 'hallucination_score': 0.998, 'repetition_score': 0.659, 'sentiment_score': 0.401, 'response_variation_score': 0.978, 'toxicity_score': 0.304, 'model_version': 'v2.6.4', 'num_edits_required': 1}
# {'topic': 'cybersecurity', 'topic_category': 'Technology', 'user_prompt': 'How do I secure our internal network from threats?', 'mock_response': 'Implement firewalls, regularly update software, use strong authentication, and conduct employee security training.', 'trace_id': 'ca9672c2-b0ef-5a22-82ac-abf972263fb5', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.5117156285905665, 'embedding_y': 0.4113053067852792, 'generation_timestamp': 1765484065.4106188, 'input_tokens': 37, 'output_tokens': 98, 'total_tokens': 135, 'latency_sec': 0.595, 'estimated_cost_usd': 8.6e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 2, 'prompt_complexity_score': 2, 'output_readability_score': 54, 'hallucination_score': 0.121, 'repetition_score': 0.965, 'sentiment_score': 0.374, 'response_variation_score': 0.053, 'toxicity_score': 0.953, 'model_version': 'v1.4.6', 'num_edits_required': 4}
# {'topic': 'cybersecurity', 'topic_category': 'Technology', 'user_prompt': 'How do I secure our internal network from threats?', 'mock_response': 'Implement firewalls, regularly update software, use strong authentication, and conduct employee security training.', 'trace_id': 'e9faf0fb-3187-50a9-a840-de401163a610', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.4733100503345301, 'embedding_y': 0.16909725322865282, 'generation_timestamp': 1765484065.412032, 'input_tokens': 74, 'output_tokens': 33, 'total_tokens': 107, 'latency_sec': 0.305, 'estimated_cost_usd': 4.1e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 2, 'prompt_complexity_score': 8, 'output_readability_score': 68, 'hallucination_score': 0.993, 'repetition_score': 0.159, 'sentiment_score': -0.847, 'response_variation_score': 0.442, 'toxicity_score': 0.672, 'model_version': 'v1.7.2', 'num_edits_required': 1}
# {'topic': 'cybersecurity', 'topic_category': 'Technology', 'user_prompt': 'How do I secure our internal network from threats?', 'mock_response': 'Implement firewalls, regularly update software, use strong authentication, and conduct employee security training.', 'trace_id': '0360acd6-87c9-5461-9fcd-f0fc48801d1c', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.557605173701012, 'embedding_y': 0.6677073344780166, 'generation_timestamp': 1765484065.4133508, 'input_tokens': 51, 'output_tokens': 168, 'total_tokens': 219, 'latency_sec': 0.793, 'estimated_cost_usd': 0.000145, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 4, 'prompt_complexity_score': 5, 'output_readability_score': 77, 'hallucination_score': 0.633, 'repetition_score': 0.993, 'sentiment_score': 0.594, 'response_variation_score': 0.765, 'toxicity_score': 0.629, 'model_version': 'v2.4.9', 'num_edits_required': 0}
# {'topic': 'cybersecurity', 'topic_category': 'Technology', 'user_prompt': 'How do I secure our internal network from threats?', 'mock_response': 'Implement firewalls, regularly update software, use strong authentication, and conduct employee security training.', 'trace_id': '5755711b-668b-59b1-aa22-5436a8a9d6a9', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.5044820775132841, 'embedding_y': 0.3159459047605594, 'generation_timestamp': 1765484065.4147594, 'input_tokens': 39, 'output_tokens': 36, 'total_tokens': 75, 'latency_sec': 0.629, 'estimated_cost_usd': 3.7e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 2, 'prompt_complexity_score': 9, 'output_readability_score': 67, 'hallucination_score': 0.602, 'repetition_score': 0.763, 'sentiment_score': 0.778, 'response_variation_score': 0.591, 'toxicity_score': 0.538, 'model_version': 'v1.7.7', 'num_edits_required': 0}
# {'topic': 'financial forecasting', 'topic_category': 'Finance', 'user_prompt': 'What techniques can I use for accurate revenue forecasting?', 'mock_response': 'Use historical data trends, regression analysis, and scenario planning to improve forecasting accuracy.', 'trace_id': '063fd774-e69e-524b-a4ec-d1e4a7c6392e', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.4977900863935638, 'embedding_y': 0.6902394324989138, 'generation_timestamp': 1765484065.4168413, 'input_tokens': 76, 'output_tokens': 55, 'total_tokens': 131, 'latency_sec': 0.579, 'estimated_cost_usd': 5.9e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 0, 'prompt_complexity_score': 5, 'output_readability_score': 85, 'hallucination_score': 0.803, 'repetition_score': 0.711, 'sentiment_score': -0.537, 'response_variation_score': 0.792, 'toxicity_score': 0.004, 'model_version': 'v1.5.2', 'num_edits_required': 5}
# {'topic': 'financial forecasting', 'topic_category': 'Finance', 'user_prompt': 'What techniques can I use for accurate revenue forecasting?', 'mock_response': 'Use historical data trends, regression analysis, and scenario planning to improve forecasting accuracy.', 'trace_id': 'c9222ca7-1248-594d-babe-eca7c58dd1de', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.2865187086300346, 'embedding_y': 0.891211393478568, 'generation_timestamp': 1765484065.4184375, 'input_tokens': 46, 'output_tokens': 132, 'total_tokens': 178, 'latency_sec': 0.953, 'estimated_cost_usd': 0.000115, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 2, 'prompt_complexity_score': 7, 'output_readability_score': 56, 'hallucination_score': 0.514, 'repetition_score': 0.038, 'sentiment_score': 0.916, 'response_variation_score': 0.692, 'toxicity_score': 0.128, 'model_version': 'v3.7.2', 'num_edits_required': 3}
# {'topic': 'financial forecasting', 'topic_category': 'Finance', 'user_prompt': 'What techniques can I use for accurate revenue forecasting?', 'mock_response': 'Use historical data trends, regression analysis, and scenario planning to improve forecasting accuracy.', 'trace_id': 'eff21e98-2a8d-5547-a304-7236e45a4ecd', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.46262885917805574, 'embedding_y': 0.3867166979812229, 'generation_timestamp': 1765484065.4207685, 'input_tokens': 34, 'output_tokens': 196, 'total_tokens': 230, 'latency_sec': 0.896, 'estimated_cost_usd': 0.000164, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 4, 'prompt_complexity_score': 7, 'output_readability_score': 74, 'hallucination_score': 0.995, 'repetition_score': 0.673, 'sentiment_score': -0.425, 'response_variation_score': 0.693, 'toxicity_score': 0.708, 'model_version': 'v2.5.8', 'num_edits_required': 2}
# {'topic': 'financial forecasting', 'topic_category': 'Finance', 'user_prompt': 'What techniques can I use for accurate revenue forecasting?', 'mock_response': 'Use historical data trends, regression analysis, and scenario planning to improve forecasting accuracy.', 'trace_id': '01e4c83f-370d-5707-b66b-9b66ac441140', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.42843431266, 'embedding_y': 0.5995481675058056, 'generation_timestamp': 1765484065.4227602, 'input_tokens': 60, 'output_tokens': 126, 'total_tokens': 186, 'latency_sec': 0.454, 'estimated_cost_usd': 0.000113, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 4, 'prompt_complexity_score': 1, 'output_readability_score': 70, 'hallucination_score': 0.456, 'repetition_score': 0.694, 'sentiment_score': 0.967, 'response_variation_score': 0.846, 'toxicity_score': 0.463, 'model_version': 'v2.3.2', 'num_edits_required': 4}
# {'topic': 'financial forecasting', 'topic_category': 'Finance', 'user_prompt': 'What techniques can I use for accurate revenue forecasting?', 'mock_response': 'Use historical data trends, regression analysis, and scenario planning to improve forecasting accuracy.', 'trace_id': 'dc7d15b3-0798-528e-ac80-8e210e29be9f', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.4473167395426817, 'embedding_y': 0.29799158939071635, 'generation_timestamp': 1765484065.4250276, 'input_tokens': 71, 'output_tokens': 30, 'total_tokens': 101, 'latency_sec': 1.354, 'estimated_cost_usd': 3.8e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 0, 'prompt_complexity_score': 4, 'output_readability_score': 69, 'hallucination_score': 0.187, 'repetition_score': 0.432, 'sentiment_score': 0.377, 'response_variation_score': 0.276, 'toxicity_score': 0.493, 'model_version': 'v3.2.5', 'num_edits_required': 2}
# {'topic': 'AI integration', 'topic_category': 'Technology', 'user_prompt': 'How can AI be integrated into our customer service process?', 'mock_response': 'AI chatbots and sentiment analysis tools can handle routine inquiries and flag urgent tickets for human agents.', 'trace_id': 'fc620e19-6edc-5f8d-8dd7-1269408c5f24', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.47469042720222937, 'embedding_y': 0.43366374784514833, 'generation_timestamp': 1765484065.4275124, 'input_tokens': 69, 'output_tokens': 173, 'total_tokens': 242, 'latency_sec': 0.118, 'estimated_cost_usd': 0.000152, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 4, 'prompt_complexity_score': 6, 'output_readability_score': 65, 'hallucination_score': 0.87, 'repetition_score': 0.137, 'sentiment_score': 0.734, 'response_variation_score': 0.4, 'toxicity_score': 0.229, 'model_version': 'v2.0.5', 'num_edits_required': 3}
# {'topic': 'AI integration', 'topic_category': 'Technology', 'user_prompt': 'How can AI be integrated into our customer service process?', 'mock_response': 'AI chatbots and sentiment analysis tools can handle routine inquiries and flag urgent tickets for human agents.', 'trace_id': 'ee828a7f-8bb4-52d1-b2ca-1f555876c3dc', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.6201495519778953, 'embedding_y': 0.34361692322491566, 'generation_timestamp': 1765484065.4293427, 'input_tokens': 64, 'output_tokens': 133, 'total_tokens': 197, 'latency_sec': 0.593, 'estimated_cost_usd': 0.000119, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 1, 'prompt_complexity_score': 6, 'output_readability_score': 53, 'hallucination_score': 0.793, 'repetition_score': 0.923, 'sentiment_score': 0.143, 'response_variation_score': 0.134, 'toxicity_score': 0.352, 'model_version': 'v3.1.2', 'num_edits_required': 3}
# {'topic': 'AI integration', 'topic_category': 'Technology', 'user_prompt': 'How can AI be integrated into our customer service process?', 'mock_response': 'AI chatbots and sentiment analysis tools can handle routine inquiries and flag urgent tickets for human agents.', 'trace_id': 'aa8b7249-d200-53bc-b02c-b06954fab41c', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.772321416650163, 'embedding_y': 0.8502862812291294, 'generation_timestamp': 1765484065.4318237, 'input_tokens': 41, 'output_tokens': 188, 'total_tokens': 229, 'latency_sec': 1.092, 'estimated_cost_usd': 0.000159, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 2, 'prompt_complexity_score': 1, 'output_readability_score': 80, 'hallucination_score': 0.5, 'repetition_score': 0.115, 'sentiment_score': 0.749, 'response_variation_score': 0.2, 'toxicity_score': 0.232, 'model_version': 'v1.5.4', 'num_edits_required': 0}
# {'topic': 'AI integration', 'topic_category': 'Technology', 'user_prompt': 'How can AI be integrated into our customer service process?', 'mock_response': 'AI chatbots and sentiment analysis tools can handle routine inquiries and flag urgent tickets for human agents.', 'trace_id': '86ad98c4-f489-5110-9fb4-fdd662214928', 'model': 'llama2-13b', 'event_type': 'jailbreak_attempt', 'embedding_x': 0.9068949414992654, 'embedding_y': 0.7652995306834358, 'generation_timestamp': 1765484065.4338324, 'input_tokens': 58, 'output_tokens': 42, 'total_tokens': 100, 'latency_sec': 0.259, 'estimated_cost_usd': 4.5e-05, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 4, 'prompt_complexity_score': 4, 'output_readability_score': 30, 'hallucination_score': 0.806, 'repetition_score': 0.731, 'sentiment_score': -0.288, 'response_variation_score': 0.964, 'toxicity_score': 0.148, 'model_version': 'v1.5.5', 'num_edits_required': 0}
# {'topic': 'AI integration', 'topic_category': 'Technology', 'user_prompt': 'How can AI be integrated into our customer service process?', 'mock_response': 'AI chatbots and sentiment analysis tools can handle routine inquiries and flag urgent tickets for human agents.', 'trace_id': '6a520fc9-258c-56b2-b5bb-03a118683f38', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.5712576940889387, 'embedding_y': 0.19907330832688092, 'generation_timestamp': 1765484065.4357903, 'input_tokens': 48, 'output_tokens': 116, 'total_tokens': 164, 'latency_sec': 0.339, 'estimated_cost_usd': 0.000102, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 0, 'prompt_complexity_score': 7, 'output_readability_score': 82, 'hallucination_score': 0.29, 'repetition_score': 0.478, 'sentiment_score': -0.201, 'response_variation_score': 0.486, 'toxicity_score': 0.338, 'model_version': 'v2.4.7', 'num_edits_required': 0}
# {'topic': 'business analytics', 'topic_category': 'Business', 'user_prompt': 'What are the best KPIs to track for a marketing campaign?', 'mock_response': 'Track conversion rate, customer acquisition cost, ROI, and engagement metrics to measure campaign effectiveness.', 'trace_id': '68121c10-4381-5512-92ae-3fbb9328b339', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.7345350657677867, 'embedding_y': 0.5748553380891409, 'generation_timestamp': 1765484065.4378996, 'input_tokens': 66, 'output_tokens': 150, 'total_tokens': 216, 'latency_sec': 1.233, 'estimated_cost_usd': 0.000133, 'num_sentences': 2, 'num_words': 14, 'num_special_tokens': 0, 'prompt_complexity_score': 10, 'output_readability_score': 34, 'hallucination_score': 0.848, 'repetition_score': 0.074, 'sentiment_score': -0.703, 'response_variation_score': 0.706, 'toxicity_score': 0.171, 'model_version': 'v1.9.5', 'num_edits_required': 5}
# {'topic': 'business analytics', 'topic_category': 'Business', 'user_prompt': 'What are the best KPIs to track for a marketing campaign?', 'mock_response': 'Track conversion rate, customer acquisition cost, ROI, and engagement metrics to measure campaign effectiveness.', 'trace_id': 'e858414e-eba1-5c71-9a78-9958c3a36c22', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.6459957918852395, 'embedding_y': 0.10383697007186554, 'generation_timestamp': 1765484065.4399307, 'input_tokens': 73, 'output_tokens': 177, 'total_tokens': 250, 'latency_sec': 0.616, 'estimated_cost_usd': 0.000156, 'num_sentences': 2, 'num_words': 14, 'num_special_tokens': 3, 'prompt_complexity_score': 4, 'output_readability_score': 90, 'hallucination_score': 0.292, 'repetition_score': 0.889, 'sentiment_score': -0.391, 'response_variation_score': 0.672, 'toxicity_score': 0.295, 'model_version': 'v1.9.8', 'num_edits_required': 2}
# {'topic': 'business analytics', 'topic_category': 'Business', 'user_prompt': 'What are the best KPIs to track for a marketing campaign?', 'mock_response': 'Track conversion rate, customer acquisition cost, ROI, and engagement metrics to measure campaign effectiveness.', 'trace_id': '763d9ed4-0f62-5ff1-92e1-c65229c914d6', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.6061213662883592, 'embedding_y': 0.22386805054249787, 'generation_timestamp': 1765484065.4413655, 'input_tokens': 74, 'output_tokens': 42, 'total_tokens': 116, 'latency_sec': 1.169, 'estimated_cost_usd': 4.8e-05, 'num_sentences': 2, 'num_words': 14, 'num_special_tokens': 4, 'prompt_complexity_score': 9, 'output_readability_score': 33, 'hallucination_score': 0.947, 'repetition_score': 0.327, 'sentiment_score': -0.898, 'response_variation_score': 0.353, 'toxicity_score': 0.746, 'model_version': 'v3.0.2', 'num_edits_required': 1}
# {'topic': 'business analytics', 'topic_category': 'Business', 'user_prompt': 'What are the best KPIs to track for a marketing campaign?', 'mock_response': 'Track conversion rate, customer acquisition cost, ROI, and engagement metrics to measure campaign effectiveness.', 'trace_id': '646ba504-fb85-5d4f-b9cf-1bfe23c4e252', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.350624051175211, 'embedding_y': 0.3550740284852913, 'generation_timestamp': 1765484065.4428043, 'input_tokens': 20, 'output_tokens': 106, 'total_tokens': 126, 'latency_sec': 1.209, 'estimated_cost_usd': 8.9e-05, 'num_sentences': 2, 'num_words': 14, 'num_special_tokens': 0, 'prompt_complexity_score': 2, 'output_readability_score': 76, 'hallucination_score': 0.204, 'repetition_score': 0.549, 'sentiment_score': 0.359, 'response_variation_score': 0.977, 'toxicity_score': 0.126, 'model_version': 'v2.6.0', 'num_edits_required': 2}
# {'topic': 'business analytics', 'topic_category': 'Business', 'user_prompt': 'What are the best KPIs to track for a marketing campaign?', 'mock_response': 'Track conversion rate, customer acquisition cost, ROI, and engagement metrics to measure campaign effectiveness.', 'trace_id': 'c6bb858d-f54d-541c-8772-ad366551abd7', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.6200839178050876, 'embedding_y': 0.3601458162954906, 'generation_timestamp': 1765484065.4442148, 'input_tokens': 37, 'output_tokens': 153, 'total_tokens': 190, 'latency_sec': 0.136, 'estimated_cost_usd': 0.00013, 'num_sentences': 2, 'num_words': 14, 'num_special_tokens': 2, 'prompt_complexity_score': 1, 'output_readability_score': 39, 'hallucination_score': 0.429, 'repetition_score': 0.867, 'sentiment_score': 0.721, 'response_variation_score': 0.267, 'toxicity_score': 0.856, 'model_version': 'v1.0.1', 'num_edits_required': 2}
# {'topic': 'investment strategy', 'topic_category': 'Finance', 'user_prompt': 'Should I diversify my portfolio internationally?', 'mock_response': 'Diversifying globally can reduce risk exposure and balance performance across different markets.', 'trace_id': '4f1c5101-8f28-588e-aa35-68727a006cb9', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.5266444410283729, 'embedding_y': 0.3884332482660885, 'generation_timestamp': 1765484065.445699, 'input_tokens': 72, 'output_tokens': 79, 'total_tokens': 151, 'latency_sec': 1.172, 'estimated_cost_usd': 7.8e-05, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 2, 'prompt_complexity_score': 10, 'output_readability_score': 73, 'hallucination_score': 0.824, 'repetition_score': 0.981, 'sentiment_score': 0.328, 'response_variation_score': 0.067, 'toxicity_score': 0.041, 'model_version': 'v1.0.5', 'num_edits_required': 3}
# {'topic': 'investment strategy', 'topic_category': 'Finance', 'user_prompt': 'Should I diversify my portfolio internationally?', 'mock_response': 'Diversifying globally can reduce risk exposure and balance performance across different markets.', 'trace_id': '3bafecb3-3ad5-54ae-b1dd-59ccbd3632cd', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.6757563114166595, 'embedding_y': 0.6168048825095094, 'generation_timestamp': 1765484065.4470558, 'input_tokens': 42, 'output_tokens': 162, 'total_tokens': 204, 'latency_sec': 0.648, 'estimated_cost_usd': 0.000138, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 3, 'prompt_complexity_score': 4, 'output_readability_score': 79, 'hallucination_score': 0.555, 'repetition_score': 0.243, 'sentiment_score': 0.312, 'response_variation_score': 0.777, 'toxicity_score': 0.332, 'model_version': 'v2.4.2', 'num_edits_required': 0}
# {'topic': 'investment strategy', 'topic_category': 'Finance', 'user_prompt': 'Should I diversify my portfolio internationally?', 'mock_response': 'Diversifying globally can reduce risk exposure and balance performance across different markets.', 'trace_id': '7bd8e384-089e-55bc-b31e-766c1f3d2185', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.48593405176896337, 'embedding_y': 0.5444526583454561, 'generation_timestamp': 1765484065.4485884, 'input_tokens': 13, 'output_tokens': 128, 'total_tokens': 141, 'latency_sec': 1.092, 'estimated_cost_usd': 0.000105, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 2, 'prompt_complexity_score': 7, 'output_readability_score': 36, 'hallucination_score': 0.677, 'repetition_score': 0.931, 'sentiment_score': 0.623, 'response_variation_score': 0.694, 'toxicity_score': 0.072, 'model_version': 'v2.4.8', 'num_edits_required': 5}
# {'topic': 'investment strategy', 'topic_category': 'Finance', 'user_prompt': 'Should I diversify my portfolio internationally?', 'mock_response': 'Diversifying globally can reduce risk exposure and balance performance across different markets.', 'trace_id': 'd6072f8d-6785-5015-bc35-555548eba6d2', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.7902664099295769, 'embedding_y': 0.37483713849835476, 'generation_timestamp': 1765484065.4500854, 'input_tokens': 10, 'output_tokens': 144, 'total_tokens': 154, 'latency_sec': 0.692, 'estimated_cost_usd': 0.000117, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 1, 'prompt_complexity_score': 3, 'output_readability_score': 49, 'hallucination_score': 0.392, 'repetition_score': 0.267, 'sentiment_score': 0.755, 'response_variation_score': 0.527, 'toxicity_score': 0.88, 'model_version': 'v2.4.7', 'num_edits_required': 1}
# {'topic': 'investment strategy', 'topic_category': 'Finance', 'user_prompt': 'Should I diversify my portfolio internationally?', 'mock_response': 'Diversifying globally can reduce risk exposure and balance performance across different markets.', 'trace_id': 'b0d3641f-cd92-5009-9cd5-ab75c0231e9e', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.05994285914058012, 'embedding_y': 0.7504551251858032, 'generation_timestamp': 1765484065.451636, 'input_tokens': 19, 'output_tokens': 139, 'total_tokens': 158, 'latency_sec': 0.879, 'estimated_cost_usd': 0.000115, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 2, 'prompt_complexity_score': 1, 'output_readability_score': 61, 'hallucination_score': 0.156, 'repetition_score': 0.918, 'sentiment_score': 0.797, 'response_variation_score': 0.3, 'toxicity_score': 0.75, 'model_version': 'v2.3.3', 'num_edits_required': 4}
# {'topic': 'DevOps', 'topic_category': 'Technology', 'user_prompt': 'How do I implement continuous integration and deployment?', 'mock_response': 'Set up automated build pipelines, run tests on commits, and deploy using container orchestration platforms like Kubernetes.', 'trace_id': '6616fa90-8d4f-522f-bca7-42e217408f0e', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.451509533914567, 'embedding_y': 0.41541219807906793, 'generation_timestamp': 1765484065.453556, 'input_tokens': 47, 'output_tokens': 65, 'total_tokens': 112, 'latency_sec': 0.783, 'estimated_cost_usd': 6.1e-05, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 5, 'prompt_complexity_score': 9, 'output_readability_score': 46, 'hallucination_score': 0.667, 'repetition_score': 0.068, 'sentiment_score': 0.072, 'response_variation_score': 0.932, 'toxicity_score': 0.837, 'model_version': 'v2.4.9', 'num_edits_required': 0}
# {'topic': 'DevOps', 'topic_category': 'Technology', 'user_prompt': 'How do I implement continuous integration and deployment?', 'mock_response': 'Set up automated build pipelines, run tests on commits, and deploy using container orchestration platforms like Kubernetes.', 'trace_id': '3fa4f9c4-a2ba-57bb-ac9a-52c4a54b3ec0', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.790393331109701, 'embedding_y': 0.2166105989503438, 'generation_timestamp': 1765484065.4562821, 'input_tokens': 10, 'output_tokens': 184, 'total_tokens': 194, 'latency_sec': 0.368, 'estimated_cost_usd': 0.000149, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 3, 'prompt_complexity_score': 4, 'output_readability_score': 50, 'hallucination_score': 0.632, 'repetition_score': 0.462, 'sentiment_score': -0.929, 'response_variation_score': 0.047, 'toxicity_score': 0.733, 'model_version': 'v1.7.5', 'num_edits_required': 4}
# {'topic': 'DevOps', 'topic_category': 'Technology', 'user_prompt': 'How do I implement continuous integration and deployment?', 'mock_response': 'Set up automated build pipelines, run tests on commits, and deploy using container orchestration platforms like Kubernetes.', 'trace_id': 'bf9e59ce-ce89-547d-869f-910cf0518560', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.43473022763252533, 'embedding_y': 0.547416175676549, 'generation_timestamp': 1765484065.4584444, 'input_tokens': 75, 'output_tokens': 170, 'total_tokens': 245, 'latency_sec': 1.139, 'estimated_cost_usd': 0.000151, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 1, 'prompt_complexity_score': 7, 'output_readability_score': 52, 'hallucination_score': 0.205, 'repetition_score': 0.525, 'sentiment_score': 0.308, 'response_variation_score': 0.477, 'toxicity_score': 0.441, 'model_version': 'v1.8.9', 'num_edits_required': 5}
# {'topic': 'DevOps', 'topic_category': 'Technology', 'user_prompt': 'How do I implement continuous integration and deployment?', 'mock_response': 'Set up automated build pipelines, run tests on commits, and deploy using container orchestration platforms like Kubernetes.', 'trace_id': '823a96fb-2abf-5ab7-a7ef-8a8db34a08d7', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.7738179404416986, 'embedding_y': 0.467614833215918, 'generation_timestamp': 1765484065.460431, 'input_tokens': 70, 'output_tokens': 164, 'total_tokens': 234, 'latency_sec': 0.495, 'estimated_cost_usd': 0.000145, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 3, 'prompt_complexity_score': 1, 'output_readability_score': 37, 'hallucination_score': 0.079, 'repetition_score': 0.264, 'sentiment_score': -0.967, 'response_variation_score': 0.469, 'toxicity_score': 0.769, 'model_version': 'v3.6.8', 'num_edits_required': 1}
# {'topic': 'DevOps', 'topic_category': 'Technology', 'user_prompt': 'How do I implement continuous integration and deployment?', 'mock_response': 'Set up automated build pipelines, run tests on commits, and deploy using container orchestration platforms like Kubernetes.', 'trace_id': '17dee00d-7d9a-559d-b371-50710b77a1dc', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.5699288087892598, 'embedding_y': 0.24892082940046562, 'generation_timestamp': 1765484065.4624014, 'input_tokens': 69, 'output_tokens': 134, 'total_tokens': 203, 'latency_sec': 1.411, 'estimated_cost_usd': 0.000121, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 2, 'prompt_complexity_score': 4, 'output_readability_score': 73, 'hallucination_score': 0.127, 'repetition_score': 0.487, 'sentiment_score': -0.942, 'response_variation_score': 0.471, 'toxicity_score': 0.416, 'model_version': 'v3.2.1', 'num_edits_required': 2}
# {'topic': 'cryptocurrency', 'topic_category': 'Finance', 'user_prompt': 'Is investing in cryptocurrency safe?', 'mock_response': 'Crypto investments are highly volatile; perform thorough research, diversify, and only invest what you can afford to lose.', 'trace_id': '205f17d8-14ad-5a39-a7f0-945fd64a3e30', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.6381750751894679, 'embedding_y': 0.3976793035723274, 'generation_timestamp': 1765484065.463981, 'input_tokens': 40, 'output_tokens': 200, 'total_tokens': 240, 'latency_sec': 1.329, 'estimated_cost_usd': 0.000168, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 1, 'prompt_complexity_score': 4, 'output_readability_score': 82, 'hallucination_score': 0.415, 'repetition_score': 0.07, 'sentiment_score': 0.329, 'response_variation_score': 0.064, 'toxicity_score': 0.564, 'model_version': 'v2.8.2', 'num_edits_required': 3}
# {'topic': 'cryptocurrency', 'topic_category': 'Finance', 'user_prompt': 'Is investing in cryptocurrency safe?', 'mock_response': 'Crypto investments are highly volatile; perform thorough research, diversify, and only invest what you can afford to lose.', 'trace_id': 'c0699ea1-b3a7-560c-9b0f-01b83069ea15', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.061843726308074554, 'embedding_y': 0.44295853094247395, 'generation_timestamp': 1765484065.4658525, 'input_tokens': 45, 'output_tokens': 39, 'total_tokens': 84, 'latency_sec': 0.513, 'estimated_cost_usd': 4e-05, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 3, 'prompt_complexity_score': 5, 'output_readability_score': 54, 'hallucination_score': 0.588, 'repetition_score': 0.513, 'sentiment_score': -0.479, 'response_variation_score': 0.07, 'toxicity_score': 0.545, 'model_version': 'v3.3.7', 'num_edits_required': 2}
# {'topic': 'cryptocurrency', 'topic_category': 'Finance', 'user_prompt': 'Is investing in cryptocurrency safe?', 'mock_response': 'Crypto investments are highly volatile; perform thorough research, diversify, and only invest what you can afford to lose.', 'trace_id': '292bb2fe-86fd-5b7d-bdab-77fef2119383', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.19646305068257974, 'embedding_y': 0.648064677000584, 'generation_timestamp': 1765484065.4673576, 'input_tokens': 57, 'output_tokens': 94, 'total_tokens': 151, 'latency_sec': 1.011, 'estimated_cost_usd': 8.7e-05, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 5, 'prompt_complexity_score': 7, 'output_readability_score': 49, 'hallucination_score': 0.548, 'repetition_score': 0.433, 'sentiment_score': -0.177, 'response_variation_score': 0.117, 'toxicity_score': 0.8, 'model_version': 'v1.3.0', 'num_edits_required': 3}
# {'topic': 'cryptocurrency', 'topic_category': 'Finance', 'user_prompt': 'Is investing in cryptocurrency safe?', 'mock_response': 'Crypto investments are highly volatile; perform thorough research, diversify, and only invest what you can afford to lose.', 'trace_id': '409780d4-8216-5028-adbd-ec00a338a203', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.23440020613732965, 'embedding_y': 0.48715229856262965, 'generation_timestamp': 1765484065.4689717, 'input_tokens': 11, 'output_tokens': 123, 'total_tokens': 134, 'latency_sec': 1.319, 'estimated_cost_usd': 0.000101, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 0, 'prompt_complexity_score': 9, 'output_readability_score': 74, 'hallucination_score': 0.289, 'repetition_score': 0.218, 'sentiment_score': -0.815, 'response_variation_score': 0.735, 'toxicity_score': 0.934, 'model_version': 'v3.5.0', 'num_edits_required': 0}
# {'topic': 'cryptocurrency', 'topic_category': 'Finance', 'user_prompt': 'Is investing in cryptocurrency safe?', 'mock_response': 'Crypto investments are highly volatile; perform thorough research, diversify, and only invest what you can afford to lose.', 'trace_id': '8961899c-379b-5662-bd9d-753fa71b7b73', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.2752887804713875, 'embedding_y': 0.7462261844920166, 'generation_timestamp': 1765484065.47043, 'input_tokens': 70, 'output_tokens': 95, 'total_tokens': 165, 'latency_sec': 0.493, 'estimated_cost_usd': 9e-05, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 2, 'prompt_complexity_score': 2, 'output_readability_score': 44, 'hallucination_score': 0.628, 'repetition_score': 0.524, 'sentiment_score': -0.761, 'response_variation_score': 0.424, 'toxicity_score': 0.666, 'model_version': 'v3.4.1', 'num_edits_required': 1}
# {'topic': 'remote work tools', 'topic_category': 'Business', 'user_prompt': 'What are effective tools for managing remote teams?', 'mock_response': 'Use Slack for communication, Asana for task management, and Zoom for video meetings to maintain collaboration.', 'trace_id': '0674ba34-4aae-58c6-bb1e-88edd7b03c57', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.5027579495784124, 'embedding_y': 0.6980202366387505, 'generation_timestamp': 1765484065.4724452, 'input_tokens': 34, 'output_tokens': 41, 'total_tokens': 75, 'latency_sec': 1.423, 'estimated_cost_usd': 4e-05, 'num_sentences': 2, 'num_words': 16, 'num_special_tokens': 5, 'prompt_complexity_score': 7, 'output_readability_score': 43, 'hallucination_score': 0.69, 'repetition_score': 0.25, 'sentiment_score': 0.279, 'response_variation_score': 0.731, 'toxicity_score': 0.804, 'model_version': 'v1.3.3', 'num_edits_required': 5}
# {'topic': 'remote work tools', 'topic_category': 'Business', 'user_prompt': 'What are effective tools for managing remote teams?', 'mock_response': 'Use Slack for communication, Asana for task management, and Zoom for video meetings to maintain collaboration.', 'trace_id': 'de8236a6-c653-53d3-a51b-5742d4df9d83', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.41818882955559444, 'embedding_y': 0.843421828266544, 'generation_timestamp': 1765484065.4757578, 'input_tokens': 15, 'output_tokens': 45, 'total_tokens': 60, 'latency_sec': 1.485, 'estimated_cost_usd': 3.9e-05, 'num_sentences': 2, 'num_words': 16, 'num_special_tokens': 0, 'prompt_complexity_score': 3, 'output_readability_score': 88, 'hallucination_score': 0.434, 'repetition_score': 0.5, 'sentiment_score': 0.642, 'response_variation_score': 0.315, 'toxicity_score': 0.659, 'model_version': 'v2.7.7', 'num_edits_required': 2}
# ...
# {'topic': 'business continuity planning', 'topic_category': 'Business', 'user_prompt': 'How do I prepare a business continuity plan?', 'mock_response': 'Identify critical processes, create backup strategies, and develop disaster recovery procedures.', 'trace_id': '10804cb6-f808-5bd1-afc9-553fd0b51a5d', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.8052963415237804, 'embedding_y': 0.38127623118514464, 'generation_timestamp': 1765484070.6455922, 'input_tokens': 37, 'output_tokens': 146, 'total_tokens': 183, 'latency_sec': 1.277, 'estimated_cost_usd': 0.000124, 'num_sentences': 2, 'num_words': 11, 'num_special_tokens': 5, 'prompt_complexity_score': 2, 'output_readability_score': 90, 'hallucination_score': 0.353, 'repetition_score': 0.325, 'sentiment_score': 0.789, 'response_variation_score': 0.721, 'toxicity_score': 0.706, 'model_version': 'v1.1.6', 'num_edits_required': 0}
# {'topic': 'equity analysis', 'topic_category': 'Finance', 'user_prompt': 'How do I evaluate the potential of a stock?', 'mock_response': 'Analyze fundamentals, growth prospects, valuation multiples, and industry trends.', 'trace_id': 'c5eae58e-800e-5e35-8c26-edbaa57310b1', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.667506503259555, 'embedding_y': 0.36859091708678243, 'generation_timestamp': 1765484070.647952, 'input_tokens': 29, 'output_tokens': 45, 'total_tokens': 74, 'latency_sec': 0.507, 'estimated_cost_usd': 4.2e-05, 'num_sentences': 2, 'num_words': 9, 'num_special_tokens': 5, 'prompt_complexity_score': 1, 'output_readability_score': 72, 'hallucination_score': 0.618, 'repetition_score': 0.615, 'sentiment_score': 0.71, 'response_variation_score': 0.959, 'toxicity_score': 0.803, 'model_version': 'v1.3.2', 'num_edits_required': 0}
# {'topic': 'equity analysis', 'topic_category': 'Finance', 'user_prompt': 'How do I evaluate the potential of a stock?', 'mock_response': 'Analyze fundamentals, growth prospects, valuation multiples, and industry trends.', 'trace_id': '488594ce-7c4a-596f-9319-3a613e288f93', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.4022221261492589, 'embedding_y': 0.5921297118933753, 'generation_timestamp': 1765484070.650442, 'input_tokens': 52, 'output_tokens': 148, 'total_tokens': 200, 'latency_sec': 0.518, 'estimated_cost_usd': 0.000129, 'num_sentences': 2, 'num_words': 9, 'num_special_tokens': 0, 'prompt_complexity_score': 5, 'output_readability_score': 50, 'hallucination_score': 0.241, 'repetition_score': 0.877, 'sentiment_score': -0.232, 'response_variation_score': 0.606, 'toxicity_score': 0.482, 'model_version': 'v1.7.9', 'num_edits_required': 0}
# {'topic': 'equity analysis', 'topic_category': 'Finance', 'user_prompt': 'How do I evaluate the potential of a stock?', 'mock_response': 'Analyze fundamentals, growth prospects, valuation multiples, and industry trends.', 'trace_id': 'bd127274-0e62-5f6e-9f7a-901dc5c7cf8e', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.4574244138800072, 'embedding_y': 0.7464675554276465, 'generation_timestamp': 1765484070.6528778, 'input_tokens': 43, 'output_tokens': 147, 'total_tokens': 190, 'latency_sec': 0.293, 'estimated_cost_usd': 0.000126, 'num_sentences': 2, 'num_words': 9, 'num_special_tokens': 5, 'prompt_complexity_score': 8, 'output_readability_score': 38, 'hallucination_score': 0.44, 'repetition_score': 0.245, 'sentiment_score': 0.82, 'response_variation_score': 0.248, 'toxicity_score': 0.291, 'model_version': 'v3.4.0', 'num_edits_required': 0}
# {'topic': 'equity analysis', 'topic_category': 'Finance', 'user_prompt': 'How do I evaluate the potential of a stock?', 'mock_response': 'Analyze fundamentals, growth prospects, valuation multiples, and industry trends.', 'trace_id': 'fc80377b-df5d-5815-a638-eb5d943eb26f', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.6452626863260014, 'embedding_y': 0.7552253476255628, 'generation_timestamp': 1765484070.6553345, 'input_tokens': 13, 'output_tokens': 102, 'total_tokens': 115, 'latency_sec': 1.47, 'estimated_cost_usd': 8.4e-05, 'num_sentences': 2, 'num_words': 9, 'num_special_tokens': 4, 'prompt_complexity_score': 6, 'output_readability_score': 87, 'hallucination_score': 0.817, 'repetition_score': 0.092, 'sentiment_score': 0.966, 'response_variation_score': 0.408, 'toxicity_score': 0.759, 'model_version': 'v3.6.2', 'num_edits_required': 4}
# {'topic': 'equity analysis', 'topic_category': 'Finance', 'user_prompt': 'How do I evaluate the potential of a stock?', 'mock_response': 'Analyze fundamentals, growth prospects, valuation multiples, and industry trends.', 'trace_id': '3ffbe0c6-79d9-5f0c-b15b-d47d365917ae', 'model': 'mistral-7b-instruct', 'event_type': 'jailbreak_attempt', 'embedding_x': 0.899100755569038, 'embedding_y': 0.963145722634491, 'generation_timestamp': 1765484070.6582701, 'input_tokens': 57, 'output_tokens': 135, 'total_tokens': 192, 'latency_sec': 0.73, 'estimated_cost_usd': 0.000119, 'num_sentences': 2, 'num_words': 9, 'num_special_tokens': 0, 'prompt_complexity_score': 1, 'output_readability_score': 35, 'hallucination_score': 0.74, 'repetition_score': 0.71, 'sentiment_score': -0.259, 'response_variation_score': 0.003, 'toxicity_score': 0.725, 'model_version': 'v3.3.4', 'num_edits_required': 4}
# {'topic': 'digital banking', 'topic_category': 'Finance', 'user_prompt': 'What are the advantages of digital banking for businesses?', 'mock_response': 'Faster transactions, lower fees, online account management, and integration with accounting tools.', 'trace_id': 'f13b484f-5194-5801-b686-7f8b724900da', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.7799067875177754, 'embedding_y': 0.6708376536551756, 'generation_timestamp': 1765484070.6613557, 'input_tokens': 41, 'output_tokens': 31, 'total_tokens': 72, 'latency_sec': 0.665, 'estimated_cost_usd': 3.3e-05, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 0, 'prompt_complexity_score': 1, 'output_readability_score': 70, 'hallucination_score': 0.311, 'repetition_score': 0.915, 'sentiment_score': 0.47, 'response_variation_score': 0.622, 'toxicity_score': 0.482, 'model_version': 'v1.2.1', 'num_edits_required': 1}
# {'topic': 'digital banking', 'topic_category': 'Finance', 'user_prompt': 'What are the advantages of digital banking for businesses?', 'mock_response': 'Faster transactions, lower fees, online account management, and integration with accounting tools.', 'trace_id': 'e9668e12-3a12-543f-b1ee-c111734bc29f', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.2241767530367617, 'embedding_y': 0.7121779200455859, 'generation_timestamp': 1765484070.6635144, 'input_tokens': 35, 'output_tokens': 35, 'total_tokens': 70, 'latency_sec': 1.284, 'estimated_cost_usd': 3.5e-05, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 1, 'prompt_complexity_score': 1, 'output_readability_score': 59, 'hallucination_score': 0.713, 'repetition_score': 0.842, 'sentiment_score': 0.932, 'response_variation_score': 0.524, 'toxicity_score': 0.497, 'model_version': 'v2.7.7', 'num_edits_required': 2}
# {'topic': 'digital banking', 'topic_category': 'Finance', 'user_prompt': 'What are the advantages of digital banking for businesses?', 'mock_response': 'Faster transactions, lower fees, online account management, and integration with accounting tools.', 'trace_id': '505f678a-9b6b-52c3-89ed-aedc02e34de3', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.2988484774196751, 'embedding_y': 0.6350351725679524, 'generation_timestamp': 1765484070.6657486, 'input_tokens': 71, 'output_tokens': 75, 'total_tokens': 146, 'latency_sec': 0.308, 'estimated_cost_usd': 7.4e-05, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 1, 'prompt_complexity_score': 10, 'output_readability_score': 76, 'hallucination_score': 0.5, 'repetition_score': 0.511, 'sentiment_score': -0.065, 'response_variation_score': 0.274, 'toxicity_score': 0.313, 'model_version': 'v3.5.4', 'num_edits_required': 2}
# {'topic': 'digital banking', 'topic_category': 'Finance', 'user_prompt': 'What are the advantages of digital banking for businesses?', 'mock_response': 'Faster transactions, lower fees, online account management, and integration with accounting tools.', 'trace_id': 'e02321bf-a640-52c4-a75d-4e440d6e994a', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.6161426961732176, 'embedding_y': 0.5405613669523466, 'generation_timestamp': 1765484070.6684587, 'input_tokens': 38, 'output_tokens': 157, 'total_tokens': 195, 'latency_sec': 0.915, 'estimated_cost_usd': 0.000133, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 2, 'prompt_complexity_score': 8, 'output_readability_score': 90, 'hallucination_score': 0.772, 'repetition_score': 0.85, 'sentiment_score': 0.906, 'response_variation_score': 0.348, 'toxicity_score': 0.605, 'model_version': 'v2.2.5', 'num_edits_required': 0}
# {'topic': 'digital banking', 'topic_category': 'Finance', 'user_prompt': 'What are the advantages of digital banking for businesses?', 'mock_response': 'Faster transactions, lower fees, online account management, and integration with accounting tools.', 'trace_id': 'a4f1699b-2ea5-58f3-91e7-3c3b19b0e8c1', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.0, 'embedding_y': 0.7137247225946464, 'generation_timestamp': 1765484070.6710503, 'input_tokens': 54, 'output_tokens': 198, 'total_tokens': 252, 'latency_sec': 0.287, 'estimated_cost_usd': 0.000169, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 2, 'prompt_complexity_score': 10, 'output_readability_score': 67, 'hallucination_score': 0.65, 'repetition_score': 0.814, 'sentiment_score': 0.718, 'response_variation_score': 0.445, 'toxicity_score': 0.574, 'model_version': 'v2.9.3', 'num_edits_required': 5}
# {'topic': 'predictive maintenance', 'topic_category': 'Technology', 'user_prompt': 'How can I implement predictive maintenance in manufacturing?', 'mock_response': 'Use IoT sensors, collect data, apply machine learning models, and schedule maintenance proactively.', 'trace_id': '9e3b9a38-fa00-56e9-bb04-5e75d2f251c8', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.48453183456251875, 'embedding_y': 0.14273476856951273, 'generation_timestamp': 1765484070.6740608, 'input_tokens': 21, 'output_tokens': 130, 'total_tokens': 151, 'latency_sec': 0.616, 'estimated_cost_usd': 0.000108, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 4, 'prompt_complexity_score': 9, 'output_readability_score': 74, 'hallucination_score': 0.057, 'repetition_score': 0.503, 'sentiment_score': -0.555, 'response_variation_score': 0.48, 'toxicity_score': 0.805, 'model_version': 'v2.5.7', 'num_edits_required': 5}
# {'topic': 'predictive maintenance', 'topic_category': 'Technology', 'user_prompt': 'How can I implement predictive maintenance in manufacturing?', 'mock_response': 'Use IoT sensors, collect data, apply machine learning models, and schedule maintenance proactively.', 'trace_id': '4dbc39ee-12ca-5703-931f-d63837058715', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.316290397498078, 'embedding_y': 0.3315241640243036, 'generation_timestamp': 1765484070.6762927, 'input_tokens': 55, 'output_tokens': 32, 'total_tokens': 87, 'latency_sec': 0.777, 'estimated_cost_usd': 3.7e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 4, 'prompt_complexity_score': 8, 'output_readability_score': 88, 'hallucination_score': 0.607, 'repetition_score': 0.161, 'sentiment_score': 0.853, 'response_variation_score': 0.82, 'toxicity_score': 0.197, 'model_version': 'v1.0.9', 'num_edits_required': 4}
# {'topic': 'predictive maintenance', 'topic_category': 'Technology', 'user_prompt': 'How can I implement predictive maintenance in manufacturing?', 'mock_response': 'Use IoT sensors, collect data, apply machine learning models, and schedule maintenance proactively.', 'trace_id': 'c08de0af-2f0b-541d-88a8-bf646f602115', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.6900545413299382, 'embedding_y': 0.7576936780738772, 'generation_timestamp': 1765484070.6790953, 'input_tokens': 80, 'output_tokens': 195, 'total_tokens': 275, 'latency_sec': 0.683, 'estimated_cost_usd': 0.000172, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 1, 'prompt_complexity_score': 3, 'output_readability_score': 31, 'hallucination_score': 0.865, 'repetition_score': 0.054, 'sentiment_score': 0.765, 'response_variation_score': 0.469, 'toxicity_score': 0.795, 'model_version': 'v2.6.3', 'num_edits_required': 4}
# {'topic': 'predictive maintenance', 'topic_category': 'Technology', 'user_prompt': 'How can I implement predictive maintenance in manufacturing?', 'mock_response': 'Use IoT sensors, collect data, apply machine learning models, and schedule maintenance proactively.', 'trace_id': 'dce76dca-2f0b-5860-b4b5-1c3a4383275d', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.6584198346395541, 'embedding_y': 0.6812147769933484, 'generation_timestamp': 1765484070.6817236, 'input_tokens': 21, 'output_tokens': 67, 'total_tokens': 88, 'latency_sec': 0.166, 'estimated_cost_usd': 5.8e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 2, 'prompt_complexity_score': 4, 'output_readability_score': 81, 'hallucination_score': 0.442, 'repetition_score': 0.106, 'sentiment_score': 0.986, 'response_variation_score': 0.939, 'toxicity_score': 0.555, 'model_version': 'v3.1.7', 'num_edits_required': 1}
# {'topic': 'predictive maintenance', 'topic_category': 'Technology', 'user_prompt': 'How can I implement predictive maintenance in manufacturing?', 'mock_response': 'Use IoT sensors, collect data, apply machine learning models, and schedule maintenance proactively.', 'trace_id': '5ddfde51-930f-5d7b-92a0-0f4f4e6858f0', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.41074254926576237, 'embedding_y': 0.7912842595372807, 'generation_timestamp': 1765484070.6847858, 'input_tokens': 10, 'output_tokens': 189, 'total_tokens': 199, 'latency_sec': 0.72, 'estimated_cost_usd': 0.000153, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 4, 'prompt_complexity_score': 2, 'output_readability_score': 70, 'hallucination_score': 0.979, 'repetition_score': 0.139, 'sentiment_score': 0.22, 'response_variation_score': 0.41, 'toxicity_score': 0.65, 'model_version': 'v1.7.2', 'num_edits_required': 3}
# {'topic': 'supply chain finance', 'topic_category': 'Business', 'user_prompt': 'How can I improve cash flow through supply chain finance?', 'mock_response': 'Use factoring, dynamic discounting, and supplier financing to optimize working capital.', 'trace_id': '7270f06a-5bcf-5cca-bb18-195d1f1e6fcf', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.6226921024689671, 'embedding_y': 0.7898475523657227, 'generation_timestamp': 1765484070.6889462, 'input_tokens': 69, 'output_tokens': 119, 'total_tokens': 188, 'latency_sec': 1.324, 'estimated_cost_usd': 0.000109, 'num_sentences': 2, 'num_words': 11, 'num_special_tokens': 3, 'prompt_complexity_score': 1, 'output_readability_score': 38, 'hallucination_score': 0.747, 'repetition_score': 0.175, 'sentiment_score': 0.232, 'response_variation_score': 0.821, 'toxicity_score': 0.57, 'model_version': 'v2.0.2', 'num_edits_required': 3}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 130
#     127                 time.sleep(0.001)
#     129 # Start streaming
# --> 130 stream_to_kafka()
#
# Cell In[1], line 127, in stream_to_kafka()
#     124 print(record)
#     126 # Control speed
# --> 127 time.sleep(0.001)
#
# KeyboardInterrupt:
