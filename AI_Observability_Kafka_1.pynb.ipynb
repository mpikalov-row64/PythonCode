# %%
import pandas as pd
import random
import time
import uuid
from kafka import KafkaProducer
import numpy as np
import json

# =========================================================
# CONFIGURATION

INPUT_CSV = r"C:\Users\mikha\OneDrive\Documents\Demos\AI Observability\OpenAI_MockResponses.csv" 
NUM_MODELS = [
    "gpt-4.1",
    "gpt-4o-mini",
    "gpt-3.5-turbo",
    "llama2-13b",
    "mistral-7b-instruct"
]

RESPONSE_QUALITY = ["Good", "Average", "Poor"]
RESPONSE_TYPE = ["Informative", "Creative", "Actionable"]
COMPLEXITY_LEVELS = ["low","medium","high"]

LATENCY_RANGE = (0.1, 1.5)
INPUT_TOKENS_RANGE = (10, 80)
OUTPUT_TOKENS_RANGE = (30, 200)
READABILITY_RANGE = (30, 90)
COMPLEXITY_RANGE = (1, 10)
RANDOM_SEED = 42
random.seed(RANDOM_SEED)

# Embedding centers for fake attack vs normal
NORMAL_CENTER = [0.5, 0.5]
ATTACK_CENTER = [0.9, 0.9]

# Kafka producer
producer = KafkaProducer(
    bootstrap_servers="localhost:9092",
    value_serializer=lambda v: json.dumps(v).encode("utf-8")
)
TOPIC_KAFKA = "llm_events"

# =========================================================
# HELPER FUNCTIONS

def mock_metrics(model_output):
    input_tokens = random.randint(*INPUT_TOKENS_RANGE)
    output_tokens = random.randint(*OUTPUT_TOKENS_RANGE)
    total_tokens = input_tokens + output_tokens
    latency = round(random.uniform(*LATENCY_RANGE), 3)
    
    num_sentences = len(model_output.split("."))
    num_words = len(model_output.split())
    
    return {
        "input_tokens": input_tokens,
        "output_tokens": output_tokens,
        "total_tokens": total_tokens,
        "latency_sec": latency,
        "estimated_cost_usd": round((input_tokens/1000)*0.0002 + (output_tokens/1000)*0.0008,6),
        "num_sentences": num_sentences,
        "num_words": num_words,
        "num_special_tokens": random.randint(0,5),
        "prompt_complexity_score": random.randint(*COMPLEXITY_RANGE),
        "output_readability_score": random.randint(*READABILITY_RANGE),
        "hallucination_score": round(random.uniform(0,1),3),
        "repetition_score": round(random.uniform(0,1),3),
        "sentiment_score": round(random.uniform(-1,1),3),
        "response_variation_score": round(random.uniform(0,1),3),
        "toxicity_score": round(random.uniform(0,1),3),
        "model_version": f"v{random.randint(1,3)}.{random.randint(0,9)}.{random.randint(0,9)}",
        "num_edits_required": random.randint(0,5)
    }

def generate_embeddings(event_type):
    if event_type == "jailbreak_attempt":
        x, y = np.random.normal(ATTACK_CENTER, 0.05, 2)
    else:
        x, y = np.random.normal(NORMAL_CENTER, 0.2, 2)
    return float(np.clip(x,0,1)), float(np.clip(y,0,1))

# =========================================================
# LOAD INPUT CSV

df_input = pd.read_csv(INPUT_CSV)
print(f"Loaded {len(df_input)} rows from {INPUT_CSV}")

# =========================================================
# STREAM EVENTS TO KAFKA

def stream_to_kafka():
    while True:
        for idx, row_input in df_input.iterrows():
            for model in NUM_MODELS:
                # Deterministic per row + model
                seed_val = RANDOM_SEED + idx + hash(model) % 10000
                random.seed(seed_val)
                
                # Randomly assign event_type
                event_type = "jailbreak_attempt" if random.random() > 0.95 else "llm_generation"
                
                # Generate embeddings
                embedding_x, embedding_y = generate_embeddings(event_type)
                
                # Generate metrics
                metrics = mock_metrics(row_input["mock_response"])
                
                record = row_input.to_dict()  # preserve all input CSV columns
                record.update({
                    "trace_id": str(uuid.uuid5(uuid.NAMESPACE_DNS, f"{idx}-{model}")),
                    "model": model,
                    "event_type": event_type,
                    "embedding_x": embedding_x,
                    "embedding_y": embedding_y,
                    "generation_timestamp": time.time(),
                })
                record.update(metrics)
                
                # Send to Kafka
                producer.send(TOPIC_KAFKA, record)
                
                # Optional: print to console
                print(record)
                
                # Control speed
                time.sleep(0.001)

# Start streaming
stream_to_kafka()
# Out:
# Loaded 110 rows from C:\Users\mikha\OneDrive\Documents\Demos\AI Observability\OpenAI_MockResponses.csv
# {'topic': 'cloud computing', 'topic_category': 'Technology', 'user_prompt': 'How can I optimize my cloud infrastructure costs?', 'mock_response': 'You can optimize cloud costs by reviewing resource utilization, using reserved instances, and automating scaling based on demand.', 'trace_id': 'f62e4d22-916f-5155-85b3-b4d96e924c5f', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.7185417595557928, 'embedding_y': 0.3420528401595899, 'generation_timestamp': 1764960366.9161189, 'input_tokens': 35, 'output_tokens': 44, 'total_tokens': 79, 'latency_sec': 0.901, 'estimated_cost_usd': 4.2e-05, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 4, 'prompt_complexity_score': 5, 'output_readability_score': 84, 'hallucination_score': 0.566, 'repetition_score': 0.829, 'sentiment_score': -0.486, 'response_variation_score': 0.68, 'toxicity_score': 0.968, 'model_version': 'v3.7.5', 'num_edits_required': 3}
# {'topic': 'cloud computing', 'topic_category': 'Technology', 'user_prompt': 'How can I optimize my cloud infrastructure costs?', 'mock_response': 'You can optimize cloud costs by reviewing resource utilization, using reserved instances, and automating scaling based on demand.', 'trace_id': '514b5188-0d5f-55e7-ae54-534804e1e3a1', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.4218653869998936, 'embedding_y': 0.43270248856822063, 'generation_timestamp': 1764960366.9422684, 'input_tokens': 30, 'output_tokens': 54, 'total_tokens': 84, 'latency_sec': 0.68, 'estimated_cost_usd': 4.9e-05, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 4, 'prompt_complexity_score': 5, 'output_readability_score': 64, 'hallucination_score': 0.519, 'repetition_score': 0.775, 'sentiment_score': -0.827, 'response_variation_score': 0.655, 'toxicity_score': 0.964, 'model_version': 'v3.0.8', 'num_edits_required': 5}
# {'topic': 'cloud computing', 'topic_category': 'Technology', 'user_prompt': 'How can I optimize my cloud infrastructure costs?', 'mock_response': 'You can optimize cloud costs by reviewing resource utilization, using reserved instances, and automating scaling based on demand.', 'trace_id': '173dc1f4-d9cf-5bf0-9d8d-3780adbdff8c', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.38681672455378013, 'embedding_y': 0.4697551977953992, 'generation_timestamp': 1764960366.9447124, 'input_tokens': 72, 'output_tokens': 174, 'total_tokens': 246, 'latency_sec': 0.832, 'estimated_cost_usd': 0.000154, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 5, 'prompt_complexity_score': 5, 'output_readability_score': 56, 'hallucination_score': 0.723, 'repetition_score': 0.255, 'sentiment_score': 0.537, 'response_variation_score': 0.305, 'toxicity_score': 0.301, 'model_version': 'v3.2.1', 'num_edits_required': 0}
# {'topic': 'cloud computing', 'topic_category': 'Technology', 'user_prompt': 'How can I optimize my cloud infrastructure costs?', 'mock_response': 'You can optimize cloud costs by reviewing resource utilization, using reserved instances, and automating scaling based on demand.', 'trace_id': '742be5e0-56dc-5648-8897-a60385bf029e', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.5210079543268973, 'embedding_y': 0.8749052873077672, 'generation_timestamp': 1764960366.947329, 'input_tokens': 29, 'output_tokens': 52, 'total_tokens': 81, 'latency_sec': 1.419, 'estimated_cost_usd': 4.7e-05, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 4, 'prompt_complexity_score': 6, 'output_readability_score': 35, 'hallucination_score': 0.193, 'repetition_score': 0.428, 'sentiment_score': -0.839, 'response_variation_score': 0.364, 'toxicity_score': 0.975, 'model_version': 'v3.1.3', 'num_edits_required': 1}
# {'topic': 'cloud computing', 'topic_category': 'Technology', 'user_prompt': 'How can I optimize my cloud infrastructure costs?', 'mock_response': 'You can optimize cloud costs by reviewing resource utilization, using reserved instances, and automating scaling based on demand.', 'trace_id': '4862e868-e287-5bcb-92ed-620d388e7031', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.8419031230044163, 'embedding_y': 0.6712107541200322, 'generation_timestamp': 1764960366.9503517, 'input_tokens': 64, 'output_tokens': 62, 'total_tokens': 126, 'latency_sec': 0.243, 'estimated_cost_usd': 6.2e-05, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 1, 'prompt_complexity_score': 10, 'output_readability_score': 72, 'hallucination_score': 0.102, 'repetition_score': 0.761, 'sentiment_score': -0.048, 'response_variation_score': 0.271, 'toxicity_score': 0.351, 'model_version': 'v2.0.1', 'num_edits_required': 2}
# {'topic': 'stock analysis', 'topic_category': 'Finance', 'user_prompt': 'What are the key metrics to evaluate a stock?', 'mock_response': 'Important metrics include P/E ratio, EPS growth, dividend yield, and debt-to-equity ratio.', 'trace_id': 'f69bd8dc-766d-566f-bc69-ec66065e4305', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.4960145808044105, 'embedding_y': 0.7683292325151021, 'generation_timestamp': 1764960366.9525843, 'input_tokens': 12, 'output_tokens': 73, 'total_tokens': 85, 'latency_sec': 1.452, 'estimated_cost_usd': 6.1e-05, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 2, 'prompt_complexity_score': 2, 'output_readability_score': 71, 'hallucination_score': 0.674, 'repetition_score': 0.078, 'sentiment_score': -0.672, 'response_variation_score': 0.224, 'toxicity_score': 0.42, 'model_version': 'v1.3.4', 'num_edits_required': 0}
# {'topic': 'stock analysis', 'topic_category': 'Finance', 'user_prompt': 'What are the key metrics to evaluate a stock?', 'mock_response': 'Important metrics include P/E ratio, EPS growth, dividend yield, and debt-to-equity ratio.', 'trace_id': '798ab045-103e-5562-85cf-4c57e0b50049', 'model': 'gpt-4o-mini', 'event_type': 'jailbreak_attempt', 'embedding_x': 0.9488788302958221, 'embedding_y': 0.8308696016940734, 'generation_timestamp': 1764960366.955179, 'input_tokens': 46, 'output_tokens': 147, 'total_tokens': 193, 'latency_sec': 0.749, 'estimated_cost_usd': 0.000127, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 1, 'prompt_complexity_score': 7, 'output_readability_score': 41, 'hallucination_score': 0.1, 'repetition_score': 0.397, 'sentiment_score': -0.665, 'response_variation_score': 0.239, 'toxicity_score': 0.27, 'model_version': 'v3.3.4', 'num_edits_required': 4}
# {'topic': 'stock analysis', 'topic_category': 'Finance', 'user_prompt': 'What are the key metrics to evaluate a stock?', 'mock_response': 'Important metrics include P/E ratio, EPS growth, dividend yield, and debt-to-equity ratio.', 'trace_id': 'dbf6f930-7702-5e71-8d31-44eb92e87bb1', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.5265794409893936, 'embedding_y': 0.2729565237531657, 'generation_timestamp': 1764960366.9566987, 'input_tokens': 79, 'output_tokens': 124, 'total_tokens': 203, 'latency_sec': 0.897, 'estimated_cost_usd': 0.000115, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 4, 'prompt_complexity_score': 7, 'output_readability_score': 53, 'hallucination_score': 0.313, 'repetition_score': 0.518, 'sentiment_score': -0.655, 'response_variation_score': 0.6, 'toxicity_score': 0.183, 'model_version': 'v3.9.3', 'num_edits_required': 5}
# {'topic': 'stock analysis', 'topic_category': 'Finance', 'user_prompt': 'What are the key metrics to evaluate a stock?', 'mock_response': 'Important metrics include P/E ratio, EPS growth, dividend yield, and debt-to-equity ratio.', 'trace_id': 'd2b1b208-2c5b-52d0-8dc9-71c9b47a5068', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.5215416073531489, 'embedding_y': 0.2367607524779683, 'generation_timestamp': 1764960366.9586873, 'input_tokens': 52, 'output_tokens': 116, 'total_tokens': 168, 'latency_sec': 0.985, 'estimated_cost_usd': 0.000103, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 2, 'prompt_complexity_score': 6, 'output_readability_score': 52, 'hallucination_score': 0.879, 'repetition_score': 0.373, 'sentiment_score': 0.817, 'response_variation_score': 0.6, 'toxicity_score': 0.274, 'model_version': 'v2.9.2', 'num_edits_required': 4}
# {'topic': 'stock analysis', 'topic_category': 'Finance', 'user_prompt': 'What are the key metrics to evaluate a stock?', 'mock_response': 'Important metrics include P/E ratio, EPS growth, dividend yield, and debt-to-equity ratio.', 'trace_id': '7babf413-4878-5425-b6db-13b75b1a525c', 'model': 'mistral-7b-instruct', 'event_type': 'jailbreak_attempt', 'embedding_x': 0.9336284375235273, 'embedding_y': 0.9873061291515043, 'generation_timestamp': 1764960366.9602885, 'input_tokens': 19, 'output_tokens': 135, 'total_tokens': 154, 'latency_sec': 0.537, 'estimated_cost_usd': 0.000112, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 3, 'prompt_complexity_score': 9, 'output_readability_score': 54, 'hallucination_score': 0.477, 'repetition_score': 0.693, 'sentiment_score': 0.936, 'response_variation_score': 0.76, 'toxicity_score': 0.894, 'model_version': 'v2.8.4', 'num_edits_required': 5}
# {'topic': 'project management', 'topic_category': 'Business', 'user_prompt': 'Can you suggest tools for tracking project progress?', 'mock_response': 'Popular tools include Jira, Asana, and Trello, which allow task assignment, progress tracking, and collaboration.', 'trace_id': 'a6cfc6a1-3feb-5fcb-90d8-29e7ac614562', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.6112052726938276, 'embedding_y': 0.8678192979000159, 'generation_timestamp': 1764960366.9619904, 'input_tokens': 61, 'output_tokens': 73, 'total_tokens': 134, 'latency_sec': 1.066, 'estimated_cost_usd': 7.1e-05, 'num_sentences': 2, 'num_words': 15, 'num_special_tokens': 5, 'prompt_complexity_score': 5, 'output_readability_score': 44, 'hallucination_score': 0.04, 'repetition_score': 0.136, 'sentiment_score': 0.08, 'response_variation_score': 0.484, 'toxicity_score': 0.849, 'model_version': 'v1.8.1', 'num_edits_required': 3}
# {'topic': 'project management', 'topic_category': 'Business', 'user_prompt': 'Can you suggest tools for tracking project progress?', 'mock_response': 'Popular tools include Jira, Asana, and Trello, which allow task assignment, progress tracking, and collaboration.', 'trace_id': '209d450b-56cd-5d9e-9771-d4d0d2971c7e', 'model': 'gpt-4o-mini', 'event_type': 'jailbreak_attempt', 'embedding_x': 0.8665158819958402, 'embedding_y': 0.8881403808815553, 'generation_timestamp': 1764960366.9635172, 'input_tokens': 39, 'output_tokens': 55, 'total_tokens': 94, 'latency_sec': 0.117, 'estimated_cost_usd': 5.2e-05, 'num_sentences': 2, 'num_words': 15, 'num_special_tokens': 3, 'prompt_complexity_score': 2, 'output_readability_score': 33, 'hallucination_score': 0.121, 'repetition_score': 0.015, 'sentiment_score': -0.896, 'response_variation_score': 0.697, 'toxicity_score': 0.171, 'model_version': 'v3.0.1', 'num_edits_required': 3}
# {'topic': 'project management', 'topic_category': 'Business', 'user_prompt': 'Can you suggest tools for tracking project progress?', 'mock_response': 'Popular tools include Jira, Asana, and Trello, which allow task assignment, progress tracking, and collaboration.', 'trace_id': '18bc972a-1c65-5e3c-8f6f-6b6ed22f5622', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.6628936960665084, 'embedding_y': 0.5495711728383453, 'generation_timestamp': 1764960366.9654, 'input_tokens': 47, 'output_tokens': 196, 'total_tokens': 243, 'latency_sec': 0.597, 'estimated_cost_usd': 0.000166, 'num_sentences': 2, 'num_words': 15, 'num_special_tokens': 0, 'prompt_complexity_score': 3, 'output_readability_score': 31, 'hallucination_score': 0.881, 'repetition_score': 0.375, 'sentiment_score': 0.719, 'response_variation_score': 0.066, 'toxicity_score': 0.629, 'model_version': 'v2.4.1', 'num_edits_required': 1}
# {'topic': 'project management', 'topic_category': 'Business', 'user_prompt': 'Can you suggest tools for tracking project progress?', 'mock_response': 'Popular tools include Jira, Asana, and Trello, which allow task assignment, progress tracking, and collaboration.', 'trace_id': 'd9e7ffeb-d25f-5dca-92fc-34c2f23cf8be', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.6615474596178437, 'embedding_y': 0.3790053092194169, 'generation_timestamp': 1764960366.9671195, 'input_tokens': 76, 'output_tokens': 37, 'total_tokens': 113, 'latency_sec': 0.671, 'estimated_cost_usd': 4.5e-05, 'num_sentences': 2, 'num_words': 15, 'num_special_tokens': 1, 'prompt_complexity_score': 3, 'output_readability_score': 85, 'hallucination_score': 0.068, 'repetition_score': 0.302, 'sentiment_score': -0.957, 'response_variation_score': 0.637, 'toxicity_score': 0.719, 'model_version': 'v1.1.1', 'num_edits_required': 1}
# {'topic': 'project management', 'topic_category': 'Business', 'user_prompt': 'Can you suggest tools for tracking project progress?', 'mock_response': 'Popular tools include Jira, Asana, and Trello, which allow task assignment, progress tracking, and collaboration.', 'trace_id': 'b7adb57b-c914-5df6-8d58-9c566334707e', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.3123165222701477, 'embedding_y': 0.5208890136096649, 'generation_timestamp': 1764960366.9690466, 'input_tokens': 58, 'output_tokens': 76, 'total_tokens': 134, 'latency_sec': 0.856, 'estimated_cost_usd': 7.2e-05, 'num_sentences': 2, 'num_words': 15, 'num_special_tokens': 1, 'prompt_complexity_score': 9, 'output_readability_score': 72, 'hallucination_score': 0.672, 'repetition_score': 0.508, 'sentiment_score': 0.152, 'response_variation_score': 0.844, 'toxicity_score': 0.06, 'model_version': 'v1.1.2', 'num_edits_required': 2}
# {'topic': 'cybersecurity', 'topic_category': 'Technology', 'user_prompt': 'How do I secure our internal network from threats?', 'mock_response': 'Implement firewalls, regularly update software, use strong authentication, and conduct employee security training.', 'trace_id': '9f586c5d-c06d-5ca8-8a7c-e21c408e8a40', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.6503820286899108, 'embedding_y': 0.42035953028229306, 'generation_timestamp': 1764960366.9711256, 'input_tokens': 40, 'output_tokens': 35, 'total_tokens': 75, 'latency_sec': 0.539, 'estimated_cost_usd': 3.6e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 5, 'prompt_complexity_score': 9, 'output_readability_score': 71, 'hallucination_score': 0.92, 'repetition_score': 0.619, 'sentiment_score': 0.138, 'response_variation_score': 0.582, 'toxicity_score': 0.643, 'model_version': 'v2.6.9', 'num_edits_required': 5}
# {'topic': 'cybersecurity', 'topic_category': 'Technology', 'user_prompt': 'How do I secure our internal network from threats?', 'mock_response': 'Implement firewalls, regularly update software, use strong authentication, and conduct employee security training.', 'trace_id': 'ca9672c2-b0ef-5a22-82ac-abf972263fb5', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.7375245056095244, 'embedding_y': 0.3105585154601832, 'generation_timestamp': 1764960366.9730332, 'input_tokens': 75, 'output_tokens': 188, 'total_tokens': 263, 'latency_sec': 0.731, 'estimated_cost_usd': 0.000165, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 1, 'prompt_complexity_score': 2, 'output_readability_score': 57, 'hallucination_score': 0.949, 'repetition_score': 0.3, 'sentiment_score': 0.452, 'response_variation_score': 0.477, 'toxicity_score': 0.093, 'model_version': 'v2.9.1', 'num_edits_required': 5}
# {'topic': 'cybersecurity', 'topic_category': 'Technology', 'user_prompt': 'How do I secure our internal network from threats?', 'mock_response': 'Implement firewalls, regularly update software, use strong authentication, and conduct employee security training.', 'trace_id': 'e9faf0fb-3187-50a9-a840-de401163a610', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.11970375226437935, 'embedding_y': 0.48727169933954484, 'generation_timestamp': 1764960366.9748862, 'input_tokens': 80, 'output_tokens': 196, 'total_tokens': 276, 'latency_sec': 1.377, 'estimated_cost_usd': 0.000173, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 2, 'prompt_complexity_score': 6, 'output_readability_score': 35, 'hallucination_score': 0.257, 'repetition_score': 0.472, 'sentiment_score': -0.971, 'response_variation_score': 0.933, 'toxicity_score': 0.055, 'model_version': 'v2.8.3', 'num_edits_required': 1}
# {'topic': 'cybersecurity', 'topic_category': 'Technology', 'user_prompt': 'How do I secure our internal network from threats?', 'mock_response': 'Implement firewalls, regularly update software, use strong authentication, and conduct employee security training.', 'trace_id': '0360acd6-87c9-5461-9fcd-f0fc48801d1c', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.6430008409409081, 'embedding_y': 0.7111605275951558, 'generation_timestamp': 1764960366.9763842, 'input_tokens': 64, 'output_tokens': 73, 'total_tokens': 137, 'latency_sec': 0.571, 'estimated_cost_usd': 7.1e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 5, 'prompt_complexity_score': 7, 'output_readability_score': 65, 'hallucination_score': 0.17, 'repetition_score': 0.067, 'sentiment_score': 0.077, 'response_variation_score': 0.839, 'toxicity_score': 0.883, 'model_version': 'v3.8.5', 'num_edits_required': 4}
# {'topic': 'cybersecurity', 'topic_category': 'Technology', 'user_prompt': 'How do I secure our internal network from threats?', 'mock_response': 'Implement firewalls, regularly update software, use strong authentication, and conduct employee security training.', 'trace_id': '5755711b-668b-59b1-aa22-5436a8a9d6a9', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.481201479087628, 'embedding_y': 0.44514882029863334, 'generation_timestamp': 1764960366.978625, 'input_tokens': 64, 'output_tokens': 47, 'total_tokens': 111, 'latency_sec': 0.877, 'estimated_cost_usd': 5e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 1, 'prompt_complexity_score': 7, 'output_readability_score': 73, 'hallucination_score': 0.613, 'repetition_score': 0.691, 'sentiment_score': 0.009, 'response_variation_score': 0.764, 'toxicity_score': 0.467, 'model_version': 'v2.0.3', 'num_edits_required': 0}
# {'topic': 'financial forecasting', 'topic_category': 'Finance', 'user_prompt': 'What techniques can I use for accurate revenue forecasting?', 'mock_response': 'Use historical data trends, regression analysis, and scenario planning to improve forecasting accuracy.', 'trace_id': '063fd774-e69e-524b-a4ec-d1e4a7c6392e', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.0019488735462291906, 'embedding_y': 0.23524866671053374, 'generation_timestamp': 1764960366.9802752, 'input_tokens': 15, 'output_tokens': 179, 'total_tokens': 194, 'latency_sec': 0.183, 'estimated_cost_usd': 0.000146, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 4, 'prompt_complexity_score': 3, 'output_readability_score': 39, 'hallucination_score': 0.928, 'repetition_score': 0.294, 'sentiment_score': -0.63, 'response_variation_score': 0.762, 'toxicity_score': 0.322, 'model_version': 'v1.1.6', 'num_edits_required': 2}
# {'topic': 'financial forecasting', 'topic_category': 'Finance', 'user_prompt': 'What techniques can I use for accurate revenue forecasting?', 'mock_response': 'Use historical data trends, regression analysis, and scenario planning to improve forecasting accuracy.', 'trace_id': 'c9222ca7-1248-594d-babe-eca7c58dd1de', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.6081806723593789, 'embedding_y': 0.18542195288414237, 'generation_timestamp': 1764960366.9816306, 'input_tokens': 13, 'output_tokens': 181, 'total_tokens': 194, 'latency_sec': 0.736, 'estimated_cost_usd': 0.000147, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 0, 'prompt_complexity_score': 7, 'output_readability_score': 54, 'hallucination_score': 0.941, 'repetition_score': 0.884, 'sentiment_score': -0.379, 'response_variation_score': 0.367, 'toxicity_score': 0.664, 'model_version': 'v1.3.5', 'num_edits_required': 4}
# {'topic': 'financial forecasting', 'topic_category': 'Finance', 'user_prompt': 'What techniques can I use for accurate revenue forecasting?', 'mock_response': 'Use historical data trends, regression analysis, and scenario planning to improve forecasting accuracy.', 'trace_id': 'eff21e98-2a8d-5547-a304-7236e45a4ecd', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.5217526233233003, 'embedding_y': 0.3535801112036565, 'generation_timestamp': 1764960366.9867353, 'input_tokens': 30, 'output_tokens': 144, 'total_tokens': 174, 'latency_sec': 0.914, 'estimated_cost_usd': 0.000121, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 3, 'prompt_complexity_score': 4, 'output_readability_score': 70, 'hallucination_score': 0.791, 'repetition_score': 0.383, 'sentiment_score': -0.181, 'response_variation_score': 0.609, 'toxicity_score': 0.419, 'model_version': 'v1.4.3', 'num_edits_required': 0}
# {'topic': 'financial forecasting', 'topic_category': 'Finance', 'user_prompt': 'What techniques can I use for accurate revenue forecasting?', 'mock_response': 'Use historical data trends, regression analysis, and scenario planning to improve forecasting accuracy.', 'trace_id': '01e4c83f-370d-5707-b66b-9b66ac441140', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.6430812205563414, 'embedding_y': 0.30434026905841816, 'generation_timestamp': 1764960366.9903119, 'input_tokens': 77, 'output_tokens': 176, 'total_tokens': 253, 'latency_sec': 0.126, 'estimated_cost_usd': 0.000156, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 4, 'prompt_complexity_score': 5, 'output_readability_score': 76, 'hallucination_score': 0.214, 'repetition_score': 0.747, 'sentiment_score': -0.385, 'response_variation_score': 0.08, 'toxicity_score': 0.105, 'model_version': 'v1.0.5', 'num_edits_required': 3}
# {'topic': 'financial forecasting', 'topic_category': 'Finance', 'user_prompt': 'What techniques can I use for accurate revenue forecasting?', 'mock_response': 'Use historical data trends, regression analysis, and scenario planning to improve forecasting accuracy.', 'trace_id': 'dc7d15b3-0798-528e-ac80-8e210e29be9f', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.5186477901414903, 'embedding_y': 0.6341568521715542, 'generation_timestamp': 1764960366.9923162, 'input_tokens': 34, 'output_tokens': 79, 'total_tokens': 113, 'latency_sec': 1.318, 'estimated_cost_usd': 7e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 0, 'prompt_complexity_score': 6, 'output_readability_score': 89, 'hallucination_score': 0.754, 'repetition_score': 0.288, 'sentiment_score': 0.532, 'response_variation_score': 0.615, 'toxicity_score': 0.536, 'model_version': 'v1.2.7', 'num_edits_required': 3}
# {'topic': 'AI integration', 'topic_category': 'Technology', 'user_prompt': 'How can AI be integrated into our customer service process?', 'mock_response': 'AI chatbots and sentiment analysis tools can handle routine inquiries and flag urgent tickets for human agents.', 'trace_id': 'fc620e19-6edc-5f8d-8dd7-1269408c5f24', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.6428399251104286, 'embedding_y': 0.2775479529702388, 'generation_timestamp': 1764960366.9950383, 'input_tokens': 38, 'output_tokens': 102, 'total_tokens': 140, 'latency_sec': 0.128, 'estimated_cost_usd': 8.9e-05, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 3, 'prompt_complexity_score': 9, 'output_readability_score': 62, 'hallucination_score': 0.912, 'repetition_score': 0.16, 'sentiment_score': -0.131, 'response_variation_score': 0.908, 'toxicity_score': 0.597, 'model_version': 'v3.7.7', 'num_edits_required': 5}
# {'topic': 'AI integration', 'topic_category': 'Technology', 'user_prompt': 'How can AI be integrated into our customer service process?', 'mock_response': 'AI chatbots and sentiment analysis tools can handle routine inquiries and flag urgent tickets for human agents.', 'trace_id': 'ee828a7f-8bb4-52d1-b2ca-1f555876c3dc', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.5976986522630567, 'embedding_y': 0.522522381869958, 'generation_timestamp': 1764960366.9974859, 'input_tokens': 52, 'output_tokens': 119, 'total_tokens': 171, 'latency_sec': 0.813, 'estimated_cost_usd': 0.000106, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 1, 'prompt_complexity_score': 1, 'output_readability_score': 48, 'hallucination_score': 0.02, 'repetition_score': 0.374, 'sentiment_score': -0.887, 'response_variation_score': 0.661, 'toxicity_score': 0.791, 'model_version': 'v2.6.9', 'num_edits_required': 2}
# {'topic': 'AI integration', 'topic_category': 'Technology', 'user_prompt': 'How can AI be integrated into our customer service process?', 'mock_response': 'AI chatbots and sentiment analysis tools can handle routine inquiries and flag urgent tickets for human agents.', 'trace_id': 'aa8b7249-d200-53bc-b02c-b06954fab41c', 'model': 'gpt-3.5-turbo', 'event_type': 'jailbreak_attempt', 'embedding_x': 0.9863988706032839, 'embedding_y': 0.8714261978257785, 'generation_timestamp': 1764960366.9992208, 'input_tokens': 68, 'output_tokens': 181, 'total_tokens': 249, 'latency_sec': 1.231, 'estimated_cost_usd': 0.000158, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 3, 'prompt_complexity_score': 7, 'output_readability_score': 72, 'hallucination_score': 0.169, 'repetition_score': 0.472, 'sentiment_score': -0.562, 'response_variation_score': 0.766, 'toxicity_score': 0.771, 'model_version': 'v1.5.4', 'num_edits_required': 2}
# {'topic': 'AI integration', 'topic_category': 'Technology', 'user_prompt': 'How can AI be integrated into our customer service process?', 'mock_response': 'AI chatbots and sentiment analysis tools can handle routine inquiries and flag urgent tickets for human agents.', 'trace_id': '86ad98c4-f489-5110-9fb4-fdd662214928', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.6025285598733013, 'embedding_y': 0.6216465250614003, 'generation_timestamp': 1764960367.00112, 'input_tokens': 14, 'output_tokens': 39, 'total_tokens': 53, 'latency_sec': 0.409, 'estimated_cost_usd': 3.4e-05, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 0, 'prompt_complexity_score': 6, 'output_readability_score': 43, 'hallucination_score': 0.485, 'repetition_score': 0.623, 'sentiment_score': -0.553, 'response_variation_score': 0.411, 'toxicity_score': 0.109, 'model_version': 'v2.1.2', 'num_edits_required': 0}
# {'topic': 'AI integration', 'topic_category': 'Technology', 'user_prompt': 'How can AI be integrated into our customer service process?', 'mock_response': 'AI chatbots and sentiment analysis tools can handle routine inquiries and flag urgent tickets for human agents.', 'trace_id': '6a520fc9-258c-56b2-b5bb-03a118683f38', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.5873917483097355, 'embedding_y': 0.6848583526347546, 'generation_timestamp': 1764960367.002953, 'input_tokens': 69, 'output_tokens': 98, 'total_tokens': 167, 'latency_sec': 1.06, 'estimated_cost_usd': 9.2e-05, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 4, 'prompt_complexity_score': 4, 'output_readability_score': 79, 'hallucination_score': 0.138, 'repetition_score': 0.557, 'sentiment_score': 0.034, 'response_variation_score': 0.277, 'toxicity_score': 0.346, 'model_version': 'v3.3.4', 'num_edits_required': 2}
# {'topic': 'business analytics', 'topic_category': 'Business', 'user_prompt': 'What are the best KPIs to track for a marketing campaign?', 'mock_response': 'Track conversion rate, customer acquisition cost, ROI, and engagement metrics to measure campaign effectiveness.', 'trace_id': '68121c10-4381-5512-92ae-3fbb9328b339', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.14202758587431036, 'embedding_y': 0.5134949817943542, 'generation_timestamp': 1764960367.005242, 'input_tokens': 55, 'output_tokens': 136, 'total_tokens': 191, 'latency_sec': 0.519, 'estimated_cost_usd': 0.00012, 'num_sentences': 2, 'num_words': 14, 'num_special_tokens': 4, 'prompt_complexity_score': 8, 'output_readability_score': 88, 'hallucination_score': 0.22, 'repetition_score': 0.043, 'sentiment_score': -0.583, 'response_variation_score': 0.915, 'toxicity_score': 0.921, 'model_version': 'v3.2.4', 'num_edits_required': 5}
# {'topic': 'business analytics', 'topic_category': 'Business', 'user_prompt': 'What are the best KPIs to track for a marketing campaign?', 'mock_response': 'Track conversion rate, customer acquisition cost, ROI, and engagement metrics to measure campaign effectiveness.', 'trace_id': 'e858414e-eba1-5c71-9a78-9958c3a36c22', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.5416190529305577, 'embedding_y': 0.6034426802456623, 'generation_timestamp': 1764960367.0075274, 'input_tokens': 22, 'output_tokens': 68, 'total_tokens': 90, 'latency_sec': 0.221, 'estimated_cost_usd': 5.9e-05, 'num_sentences': 2, 'num_words': 14, 'num_special_tokens': 3, 'prompt_complexity_score': 3, 'output_readability_score': 88, 'hallucination_score': 0.094, 'repetition_score': 0.528, 'sentiment_score': -0.364, 'response_variation_score': 0.694, 'toxicity_score': 0.316, 'model_version': 'v1.0.9', 'num_edits_required': 3}
# {'topic': 'business analytics', 'topic_category': 'Business', 'user_prompt': 'What are the best KPIs to track for a marketing campaign?', 'mock_response': 'Track conversion rate, customer acquisition cost, ROI, and engagement metrics to measure campaign effectiveness.', 'trace_id': '763d9ed4-0f62-5ff1-92e1-c65229c914d6', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.6112364846549436, 'embedding_y': 0.20180721778399624, 'generation_timestamp': 1764960367.009969, 'input_tokens': 79, 'output_tokens': 162, 'total_tokens': 241, 'latency_sec': 0.511, 'estimated_cost_usd': 0.000145, 'num_sentences': 2, 'num_words': 14, 'num_special_tokens': 2, 'prompt_complexity_score': 9, 'output_readability_score': 71, 'hallucination_score': 0.906, 'repetition_score': 0.1, 'sentiment_score': 0.634, 'response_variation_score': 0.552, 'toxicity_score': 0.796, 'model_version': 'v3.1.3', 'num_edits_required': 0}
# {'topic': 'business analytics', 'topic_category': 'Business', 'user_prompt': 'What are the best KPIs to track for a marketing campaign?', 'mock_response': 'Track conversion rate, customer acquisition cost, ROI, and engagement metrics to measure campaign effectiveness.', 'trace_id': '646ba504-fb85-5d4f-b9cf-1bfe23c4e252', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.3091341843120523, 'embedding_y': 0.4624367675595946, 'generation_timestamp': 1764960367.0117922, 'input_tokens': 11, 'output_tokens': 50, 'total_tokens': 61, 'latency_sec': 0.117, 'estimated_cost_usd': 4.2e-05, 'num_sentences': 2, 'num_words': 14, 'num_special_tokens': 5, 'prompt_complexity_score': 2, 'output_readability_score': 68, 'hallucination_score': 0.391, 'repetition_score': 0.448, 'sentiment_score': 0.911, 'response_variation_score': 0.804, 'toxicity_score': 0.572, 'model_version': 'v2.0.0', 'num_edits_required': 3}
# {'topic': 'business analytics', 'topic_category': 'Business', 'user_prompt': 'What are the best KPIs to track for a marketing campaign?', 'mock_response': 'Track conversion rate, customer acquisition cost, ROI, and engagement metrics to measure campaign effectiveness.', 'trace_id': 'c6bb858d-f54d-541c-8772-ad366551abd7', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.3097716742876139, 'embedding_y': 0.7791470641310243, 'generation_timestamp': 1764960367.0137355, 'input_tokens': 58, 'output_tokens': 93, 'total_tokens': 151, 'latency_sec': 1.485, 'estimated_cost_usd': 8.6e-05, 'num_sentences': 2, 'num_words': 14, 'num_special_tokens': 0, 'prompt_complexity_score': 1, 'output_readability_score': 48, 'hallucination_score': 0.657, 'repetition_score': 0.265, 'sentiment_score': -0.523, 'response_variation_score': 0.434, 'toxicity_score': 0.13, 'model_version': 'v2.5.2', 'num_edits_required': 3}
# {'topic': 'investment strategy', 'topic_category': 'Finance', 'user_prompt': 'Should I diversify my portfolio internationally?', 'mock_response': 'Diversifying globally can reduce risk exposure and balance performance across different markets.', 'trace_id': '4f1c5101-8f28-588e-aa35-68727a006cb9', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.597501048263613, 'embedding_y': 0.5016268257413384, 'generation_timestamp': 1764960367.015936, 'input_tokens': 52, 'output_tokens': 55, 'total_tokens': 107, 'latency_sec': 1.303, 'estimated_cost_usd': 5.4e-05, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 1, 'prompt_complexity_score': 2, 'output_readability_score': 72, 'hallucination_score': 0.04, 'repetition_score': 0.376, 'sentiment_score': 0.349, 'response_variation_score': 0.811, 'toxicity_score': 0.595, 'model_version': 'v1.4.1', 'num_edits_required': 4}
# {'topic': 'investment strategy', 'topic_category': 'Finance', 'user_prompt': 'Should I diversify my portfolio internationally?', 'mock_response': 'Diversifying globally can reduce risk exposure and balance performance across different markets.', 'trace_id': '3bafecb3-3ad5-54ae-b1dd-59ccbd3632cd', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.16225774540708043, 'embedding_y': 0.4779067791457943, 'generation_timestamp': 1764960367.018322, 'input_tokens': 54, 'output_tokens': 50, 'total_tokens': 104, 'latency_sec': 0.788, 'estimated_cost_usd': 5.1e-05, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 3, 'prompt_complexity_score': 1, 'output_readability_score': 62, 'hallucination_score': 0.912, 'repetition_score': 0.568, 'sentiment_score': 0.596, 'response_variation_score': 0.024, 'toxicity_score': 0.52, 'model_version': 'v3.2.0', 'num_edits_required': 3}
# {'topic': 'investment strategy', 'topic_category': 'Finance', 'user_prompt': 'Should I diversify my portfolio internationally?', 'mock_response': 'Diversifying globally can reduce risk exposure and balance performance across different markets.', 'trace_id': '7bd8e384-089e-55bc-b31e-766c1f3d2185', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.894115081171147, 'embedding_y': 0.7107671036427926, 'generation_timestamp': 1764960367.0202405, 'input_tokens': 68, 'output_tokens': 101, 'total_tokens': 169, 'latency_sec': 0.418, 'estimated_cost_usd': 9.4e-05, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 1, 'prompt_complexity_score': 10, 'output_readability_score': 43, 'hallucination_score': 0.412, 'repetition_score': 0.626, 'sentiment_score': -0.072, 'response_variation_score': 0.593, 'toxicity_score': 0.845, 'model_version': 'v3.9.6', 'num_edits_required': 0}
# {'topic': 'investment strategy', 'topic_category': 'Finance', 'user_prompt': 'Should I diversify my portfolio internationally?', 'mock_response': 'Diversifying globally can reduce risk exposure and balance performance across different markets.', 'trace_id': 'd6072f8d-6785-5015-bc35-555548eba6d2', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.2885684445909006, 'embedding_y': 0.32384020885608883, 'generation_timestamp': 1764960367.0217974, 'input_tokens': 80, 'output_tokens': 84, 'total_tokens': 164, 'latency_sec': 0.559, 'estimated_cost_usd': 8.3e-05, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 0, 'prompt_complexity_score': 10, 'output_readability_score': 76, 'hallucination_score': 0.565, 'repetition_score': 0.38, 'sentiment_score': -0.499, 'response_variation_score': 0.723, 'toxicity_score': 0.064, 'model_version': 'v3.3.3', 'num_edits_required': 5}
# {'topic': 'investment strategy', 'topic_category': 'Finance', 'user_prompt': 'Should I diversify my portfolio internationally?', 'mock_response': 'Diversifying globally can reduce risk exposure and balance performance across different markets.', 'trace_id': 'b0d3641f-cd92-5009-9cd5-ab75c0231e9e', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.532375083362191, 'embedding_y': 0.883132322008271, 'generation_timestamp': 1764960367.0239196, 'input_tokens': 16, 'output_tokens': 179, 'total_tokens': 195, 'latency_sec': 0.578, 'estimated_cost_usd': 0.000146, 'num_sentences': 2, 'num_words': 12, 'num_special_tokens': 2, 'prompt_complexity_score': 7, 'output_readability_score': 78, 'hallucination_score': 0.889, 'repetition_score': 0.437, 'sentiment_score': 0.225, 'response_variation_score': 0.577, 'toxicity_score': 0.14, 'model_version': 'v1.2.6', 'num_edits_required': 3}
# {'topic': 'DevOps', 'topic_category': 'Technology', 'user_prompt': 'How do I implement continuous integration and deployment?', 'mock_response': 'Set up automated build pipelines, run tests on commits, and deploy using container orchestration platforms like Kubernetes.', 'trace_id': '6616fa90-8d4f-522f-bca7-42e217408f0e', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.6183967804564021, 'embedding_y': 0.15912181013725818, 'generation_timestamp': 1764960367.0260582, 'input_tokens': 33, 'output_tokens': 153, 'total_tokens': 186, 'latency_sec': 0.767, 'estimated_cost_usd': 0.000129, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 3, 'prompt_complexity_score': 2, 'output_readability_score': 66, 'hallucination_score': 0.025, 'repetition_score': 0.346, 'sentiment_score': 0.405, 'response_variation_score': 0.497, 'toxicity_score': 0.15, 'model_version': 'v2.4.7', 'num_edits_required': 1}
# {'topic': 'DevOps', 'topic_category': 'Technology', 'user_prompt': 'How do I implement continuous integration and deployment?', 'mock_response': 'Set up automated build pipelines, run tests on commits, and deploy using container orchestration platforms like Kubernetes.', 'trace_id': '3fa4f9c4-a2ba-57bb-ac9a-52c4a54b3ec0', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.3732677192007292, 'embedding_y': 0.30355531606815345, 'generation_timestamp': 1764960367.0276258, 'input_tokens': 11, 'output_tokens': 48, 'total_tokens': 59, 'latency_sec': 0.269, 'estimated_cost_usd': 4.1e-05, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 4, 'prompt_complexity_score': 10, 'output_readability_score': 71, 'hallucination_score': 0.981, 'repetition_score': 0.278, 'sentiment_score': 0.022, 'response_variation_score': 0.443, 'toxicity_score': 0.398, 'model_version': 'v3.0.4', 'num_edits_required': 2}
# {'topic': 'DevOps', 'topic_category': 'Technology', 'user_prompt': 'How do I implement continuous integration and deployment?', 'mock_response': 'Set up automated build pipelines, run tests on commits, and deploy using container orchestration platforms like Kubernetes.', 'trace_id': 'bf9e59ce-ce89-547d-869f-910cf0518560', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.7670133322697298, 'embedding_y': 0.38141765822603035, 'generation_timestamp': 1764960367.0299602, 'input_tokens': 78, 'output_tokens': 155, 'total_tokens': 233, 'latency_sec': 0.607, 'estimated_cost_usd': 0.00014, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 5, 'prompt_complexity_score': 4, 'output_readability_score': 54, 'hallucination_score': 0.738, 'repetition_score': 0.64, 'sentiment_score': -0.719, 'response_variation_score': 0.624, 'toxicity_score': 0.288, 'model_version': 'v3.5.3', 'num_edits_required': 5}
# {'topic': 'DevOps', 'topic_category': 'Technology', 'user_prompt': 'How do I implement continuous integration and deployment?', 'mock_response': 'Set up automated build pipelines, run tests on commits, and deploy using container orchestration platforms like Kubernetes.', 'trace_id': '823a96fb-2abf-5ab7-a7ef-8a8db34a08d7', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.32144710403737087, 'embedding_y': 0.4511170106529233, 'generation_timestamp': 1764960367.0316164, 'input_tokens': 10, 'output_tokens': 37, 'total_tokens': 47, 'latency_sec': 1.491, 'estimated_cost_usd': 3.2e-05, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 4, 'prompt_complexity_score': 8, 'output_readability_score': 31, 'hallucination_score': 0.272, 'repetition_score': 0.597, 'sentiment_score': 0.838, 'response_variation_score': 0.443, 'toxicity_score': 0.32, 'model_version': 'v1.9.4', 'num_edits_required': 4}
# {'topic': 'DevOps', 'topic_category': 'Technology', 'user_prompt': 'How do I implement continuous integration and deployment?', 'mock_response': 'Set up automated build pipelines, run tests on commits, and deploy using container orchestration platforms like Kubernetes.', 'trace_id': '17dee00d-7d9a-559d-b371-50710b77a1dc', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.7018529531984912, 'embedding_y': 0.2045718245303597, 'generation_timestamp': 1764960367.0342014, 'input_tokens': 78, 'output_tokens': 128, 'total_tokens': 206, 'latency_sec': 0.924, 'estimated_cost_usd': 0.000118, 'num_sentences': 2, 'num_words': 17, 'num_special_tokens': 3, 'prompt_complexity_score': 5, 'output_readability_score': 34, 'hallucination_score': 0.966, 'repetition_score': 0.773, 'sentiment_score': -0.057, 'response_variation_score': 0.792, 'toxicity_score': 0.211, 'model_version': 'v1.0.1', 'num_edits_required': 1}
# {'topic': 'cryptocurrency', 'topic_category': 'Finance', 'user_prompt': 'Is investing in cryptocurrency safe?', 'mock_response': 'Crypto investments are highly volatile; perform thorough research, diversify, and only invest what you can afford to lose.', 'trace_id': '205f17d8-14ad-5a39-a7f0-945fd64a3e30', 'model': 'gpt-4.1', 'event_type': 'jailbreak_attempt', 'embedding_x': 0.7811218491232457, 'embedding_y': 0.9117628818782052, 'generation_timestamp': 1764960367.0360286, 'input_tokens': 40, 'output_tokens': 77, 'total_tokens': 117, 'latency_sec': 0.452, 'estimated_cost_usd': 7e-05, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 1, 'prompt_complexity_score': 2, 'output_readability_score': 51, 'hallucination_score': 0.15, 'repetition_score': 0.748, 'sentiment_score': 0.315, 'response_variation_score': 0.889, 'toxicity_score': 0.55, 'model_version': 'v3.8.3', 'num_edits_required': 0}
# {'topic': 'cryptocurrency', 'topic_category': 'Finance', 'user_prompt': 'Is investing in cryptocurrency safe?', 'mock_response': 'Crypto investments are highly volatile; perform thorough research, diversify, and only invest what you can afford to lose.', 'trace_id': 'c0699ea1-b3a7-560c-9b0f-01b83069ea15', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.746071508161976, 'embedding_y': 0.5890680542049463, 'generation_timestamp': 1764960367.0385864, 'input_tokens': 14, 'output_tokens': 93, 'total_tokens': 107, 'latency_sec': 0.892, 'estimated_cost_usd': 7.7e-05, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 3, 'prompt_complexity_score': 9, 'output_readability_score': 76, 'hallucination_score': 0.431, 'repetition_score': 0.362, 'sentiment_score': 0.193, 'response_variation_score': 0.184, 'toxicity_score': 0.998, 'model_version': 'v1.5.5', 'num_edits_required': 4}
# {'topic': 'cryptocurrency', 'topic_category': 'Finance', 'user_prompt': 'Is investing in cryptocurrency safe?', 'mock_response': 'Crypto investments are highly volatile; perform thorough research, diversify, and only invest what you can afford to lose.', 'trace_id': '292bb2fe-86fd-5b7d-bdab-77fef2119383', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.574016293095227, 'embedding_y': 0.2608784203751277, 'generation_timestamp': 1764960367.040563, 'input_tokens': 28, 'output_tokens': 132, 'total_tokens': 160, 'latency_sec': 1.302, 'estimated_cost_usd': 0.000111, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 0, 'prompt_complexity_score': 4, 'output_readability_score': 80, 'hallucination_score': 0.368, 'repetition_score': 0.187, 'sentiment_score': 0.278, 'response_variation_score': 0.808, 'toxicity_score': 0.553, 'model_version': 'v3.9.2', 'num_edits_required': 4}
# {'topic': 'cryptocurrency', 'topic_category': 'Finance', 'user_prompt': 'Is investing in cryptocurrency safe?', 'mock_response': 'Crypto investments are highly volatile; perform thorough research, diversify, and only invest what you can afford to lose.', 'trace_id': '409780d4-8216-5028-adbd-ec00a338a203', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.3828572046862292, 'embedding_y': 0.39148324506322085, 'generation_timestamp': 1764960367.0425851, 'input_tokens': 63, 'output_tokens': 139, 'total_tokens': 202, 'latency_sec': 0.989, 'estimated_cost_usd': 0.000124, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 5, 'prompt_complexity_score': 7, 'output_readability_score': 31, 'hallucination_score': 0.43, 'repetition_score': 0.234, 'sentiment_score': 0.574, 'response_variation_score': 0.156, 'toxicity_score': 0.03, 'model_version': 'v2.4.7', 'num_edits_required': 1}
# {'topic': 'cryptocurrency', 'topic_category': 'Finance', 'user_prompt': 'Is investing in cryptocurrency safe?', 'mock_response': 'Crypto investments are highly volatile; perform thorough research, diversify, and only invest what you can afford to lose.', 'trace_id': '8961899c-379b-5662-bd9d-753fa71b7b73', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.42136754408470767, 'embedding_y': 0.5543921102262308, 'generation_timestamp': 1764960367.0452948, 'input_tokens': 60, 'output_tokens': 70, 'total_tokens': 130, 'latency_sec': 0.541, 'estimated_cost_usd': 6.8e-05, 'num_sentences': 2, 'num_words': 18, 'num_special_tokens': 5, 'prompt_complexity_score': 2, 'output_readability_score': 67, 'hallucination_score': 0.133, 'repetition_score': 0.59, 'sentiment_score': 0.892, 'response_variation_score': 0.288, 'toxicity_score': 0.797, 'model_version': 'v3.5.9', 'num_edits_required': 5}
# {'topic': 'remote work tools', 'topic_category': 'Business', 'user_prompt': 'What are effective tools for managing remote teams?', 'mock_response': 'Use Slack for communication, Asana for task management, and Zoom for video meetings to maintain collaboration.', 'trace_id': '0674ba34-4aae-58c6-bb1e-88edd7b03c57', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.40585013946564685, 'embedding_y': 0.4685194840430094, 'generation_timestamp': 1764960367.0468364, 'input_tokens': 23, 'output_tokens': 183, 'total_tokens': 206, 'latency_sec': 0.589, 'estimated_cost_usd': 0.000151, 'num_sentences': 2, 'num_words': 16, 'num_special_tokens': 1, 'prompt_complexity_score': 1, 'output_readability_score': 62, 'hallucination_score': 0.738, 'repetition_score': 0.35, 'sentiment_score': -0.608, 'response_variation_score': 0.33, 'toxicity_score': 0.249, 'model_version': 'v3.9.7', 'num_edits_required': 3}
# {'topic': 'remote work tools', 'topic_category': 'Business', 'user_prompt': 'What are effective tools for managing remote teams?', 'mock_response': 'Use Slack for communication, Asana for task management, and Zoom for video meetings to maintain collaboration.', 'trace_id': 'de8236a6-c653-53d3-a51b-5742d4df9d83', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.3734097874521489, 'embedding_y': 0.5211063328218944, 'generation_timestamp': 1764960367.0515614, 'input_tokens': 48, 'output_tokens': 151, 'total_tokens': 199, 'latency_sec': 1.097, 'estimated_cost_usd': 0.00013, 'num_sentences': 2, 'num_words': 16, 'num_special_tokens': 5, 'prompt_complexity_score': 1, 'output_readability_score': 89, 'hallucination_score': 0.519, 'repetition_score': 0.163, 'sentiment_score': -0.11, 'response_variation_score': 0.558, 'toxicity_score': 0.67, 'model_version': 'v3.9.0', 'num_edits_required': 0}
# ...
# {'topic': 'IoT development', 'topic_category': 'Technology', 'user_prompt': 'How do I secure IoT devices in a smart home?', 'mock_response': 'Use strong passwords, network segmentation, firmware updates, and encrypted communication.', 'trace_id': '0b370c68-bd08-5107-9b2d-03a4f40bf734', 'model': 'mistral-7b-instruct', 'event_type': 'jailbreak_attempt', 'embedding_x': 0.8971709182452219, 'embedding_y': 0.9383785962851117, 'generation_timestamp': 1764960376.8412054, 'input_tokens': 60, 'output_tokens': 65, 'total_tokens': 125, 'latency_sec': 1.438, 'estimated_cost_usd': 6.4e-05, 'num_sentences': 2, 'num_words': 10, 'num_special_tokens': 0, 'prompt_complexity_score': 1, 'output_readability_score': 70, 'hallucination_score': 0.699, 'repetition_score': 0.3, 'sentiment_score': -0.833, 'response_variation_score': 0.329, 'toxicity_score': 0.93, 'model_version': 'v1.2.0', 'num_edits_required': 3}
# {'topic': 'business growth', 'topic_category': 'Business', 'user_prompt': 'What strategies can boost small business revenue?', 'mock_response': 'Focus on customer retention, digital marketing, product diversification, and strategic partnerships.', 'trace_id': 'dadbd566-d6ca-5b00-8fd0-0abc408dfea3', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.7283777493944589, 'embedding_y': 0.39003922182056217, 'generation_timestamp': 1764960376.8447785, 'input_tokens': 58, 'output_tokens': 134, 'total_tokens': 192, 'latency_sec': 1.312, 'estimated_cost_usd': 0.000119, 'num_sentences': 2, 'num_words': 11, 'num_special_tokens': 5, 'prompt_complexity_score': 4, 'output_readability_score': 34, 'hallucination_score': 0.867, 'repetition_score': 0.063, 'sentiment_score': -0.44, 'response_variation_score': 0.325, 'toxicity_score': 0.548, 'model_version': 'v1.5.3', 'num_edits_required': 1}
# {'topic': 'business growth', 'topic_category': 'Business', 'user_prompt': 'What strategies can boost small business revenue?', 'mock_response': 'Focus on customer retention, digital marketing, product diversification, and strategic partnerships.', 'trace_id': '8a66f180-b450-58e4-9e5d-e0f312cb516a', 'model': 'gpt-4o-mini', 'event_type': 'jailbreak_attempt', 'embedding_x': 1.0, 'embedding_y': 0.9057072294325874, 'generation_timestamp': 1764960376.8488402, 'input_tokens': 79, 'output_tokens': 143, 'total_tokens': 222, 'latency_sec': 0.291, 'estimated_cost_usd': 0.00013, 'num_sentences': 2, 'num_words': 11, 'num_special_tokens': 1, 'prompt_complexity_score': 2, 'output_readability_score': 64, 'hallucination_score': 0.655, 'repetition_score': 0.633, 'sentiment_score': 0.035, 'response_variation_score': 0.876, 'toxicity_score': 0.672, 'model_version': 'v3.0.9', 'num_edits_required': 4}
# {'topic': 'business growth', 'topic_category': 'Business', 'user_prompt': 'What strategies can boost small business revenue?', 'mock_response': 'Focus on customer retention, digital marketing, product diversification, and strategic partnerships.', 'trace_id': '0028dad4-f1f9-5fe9-a1d2-3cb08232fd8b', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.37414473636828394, 'embedding_y': 0.8796084787173553, 'generation_timestamp': 1764960376.852013, 'input_tokens': 11, 'output_tokens': 187, 'total_tokens': 198, 'latency_sec': 0.424, 'estimated_cost_usd': 0.000152, 'num_sentences': 2, 'num_words': 11, 'num_special_tokens': 0, 'prompt_complexity_score': 3, 'output_readability_score': 53, 'hallucination_score': 0.449, 'repetition_score': 0.514, 'sentiment_score': 0.114, 'response_variation_score': 0.629, 'toxicity_score': 0.303, 'model_version': 'v2.5.9', 'num_edits_required': 0}
# {'topic': 'business growth', 'topic_category': 'Business', 'user_prompt': 'What strategies can boost small business revenue?', 'mock_response': 'Focus on customer retention, digital marketing, product diversification, and strategic partnerships.', 'trace_id': '99627c5b-ef77-5b30-9310-88d61339f1e2', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.1743134791784801, 'embedding_y': 0.6128442741120668, 'generation_timestamp': 1764960376.8557148, 'input_tokens': 24, 'output_tokens': 72, 'total_tokens': 96, 'latency_sec': 0.112, 'estimated_cost_usd': 6.2e-05, 'num_sentences': 2, 'num_words': 11, 'num_special_tokens': 1, 'prompt_complexity_score': 5, 'output_readability_score': 35, 'hallucination_score': 0.404, 'repetition_score': 0.97, 'sentiment_score': -0.256, 'response_variation_score': 0.725, 'toxicity_score': 0.198, 'model_version': 'v2.5.0', 'num_edits_required': 0}
# {'topic': 'business growth', 'topic_category': 'Business', 'user_prompt': 'What strategies can boost small business revenue?', 'mock_response': 'Focus on customer retention, digital marketing, product diversification, and strategic partnerships.', 'trace_id': '523f3e9e-91b9-5ea2-ab18-85df5c99557b', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.6646339315012509, 'embedding_y': 1.0, 'generation_timestamp': 1764960376.86047, 'input_tokens': 37, 'output_tokens': 87, 'total_tokens': 124, 'latency_sec': 1.175, 'estimated_cost_usd': 7.7e-05, 'num_sentences': 2, 'num_words': 11, 'num_special_tokens': 1, 'prompt_complexity_score': 6, 'output_readability_score': 90, 'hallucination_score': 0.072, 'repetition_score': 0.454, 'sentiment_score': 0.846, 'response_variation_score': 0.901, 'toxicity_score': 0.625, 'model_version': 'v2.5.2', 'num_edits_required': 0}
# {'topic': 'asset management', 'topic_category': 'Finance', 'user_prompt': 'How do I evaluate the performance of my assets?', 'mock_response': 'Track ROI, risk-adjusted returns, and benchmark performance against market indices.', 'trace_id': '1472a1ce-21bc-5f75-8740-e5f1cf01af13', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.5158492742291709, 'embedding_y': 0.35517258015898245, 'generation_timestamp': 1764960376.8645294, 'input_tokens': 42, 'output_tokens': 134, 'total_tokens': 176, 'latency_sec': 1.027, 'estimated_cost_usd': 0.000116, 'num_sentences': 2, 'num_words': 10, 'num_special_tokens': 1, 'prompt_complexity_score': 1, 'output_readability_score': 75, 'hallucination_score': 0.5, 'repetition_score': 0.976, 'sentiment_score': 0.465, 'response_variation_score': 0.676, 'toxicity_score': 0.89, 'model_version': 'v2.0.1', 'num_edits_required': 1}
# {'topic': 'asset management', 'topic_category': 'Finance', 'user_prompt': 'How do I evaluate the performance of my assets?', 'mock_response': 'Track ROI, risk-adjusted returns, and benchmark performance against market indices.', 'trace_id': '1bd2c042-bcc5-5744-9967-9191f5916053', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.5452164081462801, 'embedding_y': 0.5832863305553305, 'generation_timestamp': 1764960376.867462, 'input_tokens': 40, 'output_tokens': 175, 'total_tokens': 215, 'latency_sec': 1.316, 'estimated_cost_usd': 0.000148, 'num_sentences': 2, 'num_words': 10, 'num_special_tokens': 5, 'prompt_complexity_score': 9, 'output_readability_score': 66, 'hallucination_score': 0.775, 'repetition_score': 0.164, 'sentiment_score': 0.924, 'response_variation_score': 0.725, 'toxicity_score': 0.138, 'model_version': 'v1.3.1', 'num_edits_required': 0}
# {'topic': 'asset management', 'topic_category': 'Finance', 'user_prompt': 'How do I evaluate the performance of my assets?', 'mock_response': 'Track ROI, risk-adjusted returns, and benchmark performance against market indices.', 'trace_id': 'd782828d-1cb6-58f0-b9b1-7171c3424cb5', 'model': 'gpt-3.5-turbo', 'event_type': 'llm_generation', 'embedding_x': 0.6608911225125582, 'embedding_y': 0.5497585896295503, 'generation_timestamp': 1764960376.871035, 'input_tokens': 33, 'output_tokens': 138, 'total_tokens': 171, 'latency_sec': 0.671, 'estimated_cost_usd': 0.000117, 'num_sentences': 2, 'num_words': 10, 'num_special_tokens': 0, 'prompt_complexity_score': 2, 'output_readability_score': 54, 'hallucination_score': 0.467, 'repetition_score': 0.515, 'sentiment_score': -0.264, 'response_variation_score': 0.561, 'toxicity_score': 0.959, 'model_version': 'v3.0.2', 'num_edits_required': 4}
# {'topic': 'asset management', 'topic_category': 'Finance', 'user_prompt': 'How do I evaluate the performance of my assets?', 'mock_response': 'Track ROI, risk-adjusted returns, and benchmark performance against market indices.', 'trace_id': '2940d363-ac32-5cbe-b52e-d5185dc0d10f', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.5657306326090629, 'embedding_y': 0.35330871567295863, 'generation_timestamp': 1764960376.876231, 'input_tokens': 80, 'output_tokens': 74, 'total_tokens': 154, 'latency_sec': 0.601, 'estimated_cost_usd': 7.5e-05, 'num_sentences': 2, 'num_words': 10, 'num_special_tokens': 2, 'prompt_complexity_score': 1, 'output_readability_score': 77, 'hallucination_score': 0.244, 'repetition_score': 0.946, 'sentiment_score': -0.801, 'response_variation_score': 0.054, 'toxicity_score': 0.414, 'model_version': 'v1.6.8', 'num_edits_required': 3}
# {'topic': 'asset management', 'topic_category': 'Finance', 'user_prompt': 'How do I evaluate the performance of my assets?', 'mock_response': 'Track ROI, risk-adjusted returns, and benchmark performance against market indices.', 'trace_id': '3c8df854-877a-569e-b21c-d15974d7dfd1', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.09969323804624852, 'embedding_y': 0.4227648588900839, 'generation_timestamp': 1764960376.8799586, 'input_tokens': 42, 'output_tokens': 52, 'total_tokens': 94, 'latency_sec': 1.457, 'estimated_cost_usd': 5e-05, 'num_sentences': 2, 'num_words': 10, 'num_special_tokens': 2, 'prompt_complexity_score': 9, 'output_readability_score': 55, 'hallucination_score': 0.3, 'repetition_score': 0.28, 'sentiment_score': 0.03, 'response_variation_score': 0.724, 'toxicity_score': 0.974, 'model_version': 'v2.8.1', 'num_edits_required': 4}
# {'topic': 'cloud architecture', 'topic_category': 'Technology', 'user_prompt': 'What is multi-cloud deployment?', 'mock_response': 'Deploying applications across multiple cloud providers to increase reliability and avoid vendor lock-in.', 'trace_id': '9595b75b-0e2e-577d-8218-e8809e907e54', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.6277128559893039, 'embedding_y': 0.4143760029076808, 'generation_timestamp': 1764960376.883168, 'input_tokens': 15, 'output_tokens': 125, 'total_tokens': 140, 'latency_sec': 0.955, 'estimated_cost_usd': 0.000103, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 1, 'prompt_complexity_score': 9, 'output_readability_score': 73, 'hallucination_score': 0.54, 'repetition_score': 0.257, 'sentiment_score': 0.798, 'response_variation_score': 0.585, 'toxicity_score': 0.954, 'model_version': 'v3.7.4', 'num_edits_required': 3}
# {'topic': 'cloud architecture', 'topic_category': 'Technology', 'user_prompt': 'What is multi-cloud deployment?', 'mock_response': 'Deploying applications across multiple cloud providers to increase reliability and avoid vendor lock-in.', 'trace_id': '8ed7e4e6-bbab-55d0-9d18-0c1ef86904c6', 'model': 'gpt-4o-mini', 'event_type': 'llm_generation', 'embedding_x': 0.4196508714009318, 'embedding_y': 0.5372602552602324, 'generation_timestamp': 1764960376.8866699, 'input_tokens': 47, 'output_tokens': 197, 'total_tokens': 244, 'latency_sec': 0.454, 'estimated_cost_usd': 0.000167, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 1, 'prompt_complexity_score': 5, 'output_readability_score': 58, 'hallucination_score': 0.149, 'repetition_score': 0.468, 'sentiment_score': -0.205, 'response_variation_score': 0.815, 'toxicity_score': 0.025, 'model_version': 'v3.0.4', 'num_edits_required': 0}
# {'topic': 'cloud architecture', 'topic_category': 'Technology', 'user_prompt': 'What is multi-cloud deployment?', 'mock_response': 'Deploying applications across multiple cloud providers to increase reliability and avoid vendor lock-in.', 'trace_id': '9db36c5e-a70d-5efd-9859-32921a452d87', 'model': 'gpt-3.5-turbo', 'event_type': 'jailbreak_attempt', 'embedding_x': 0.8812954341938779, 'embedding_y': 0.8892074640171045, 'generation_timestamp': 1764960376.890585, 'input_tokens': 71, 'output_tokens': 149, 'total_tokens': 220, 'latency_sec': 1.006, 'estimated_cost_usd': 0.000133, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 2, 'prompt_complexity_score': 8, 'output_readability_score': 68, 'hallucination_score': 0.306, 'repetition_score': 0.117, 'sentiment_score': -0.565, 'response_variation_score': 0.557, 'toxicity_score': 0.003, 'model_version': 'v1.4.7', 'num_edits_required': 1}
# {'topic': 'cloud architecture', 'topic_category': 'Technology', 'user_prompt': 'What is multi-cloud deployment?', 'mock_response': 'Deploying applications across multiple cloud providers to increase reliability and avoid vendor lock-in.', 'trace_id': '191ffced-fb92-5c7c-8523-88cc1d16d46c', 'model': 'llama2-13b', 'event_type': 'llm_generation', 'embedding_x': 0.2514100565208034, 'embedding_y': 0.696551007938899, 'generation_timestamp': 1764960376.8934715, 'input_tokens': 19, 'output_tokens': 86, 'total_tokens': 105, 'latency_sec': 1.442, 'estimated_cost_usd': 7.3e-05, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 3, 'prompt_complexity_score': 6, 'output_readability_score': 39, 'hallucination_score': 0.426, 'repetition_score': 0.007, 'sentiment_score': -0.188, 'response_variation_score': 0.52, 'toxicity_score': 0.97, 'model_version': 'v1.2.0', 'num_edits_required': 2}
# {'topic': 'cloud architecture', 'topic_category': 'Technology', 'user_prompt': 'What is multi-cloud deployment?', 'mock_response': 'Deploying applications across multiple cloud providers to increase reliability and avoid vendor lock-in.', 'trace_id': 'a96ab70d-8fbc-539d-b5dd-95054e713aaa', 'model': 'mistral-7b-instruct', 'event_type': 'llm_generation', 'embedding_x': 0.2687647750566866, 'embedding_y': 0.6819985161699111, 'generation_timestamp': 1764960376.89677, 'input_tokens': 72, 'output_tokens': 137, 'total_tokens': 209, 'latency_sec': 0.965, 'estimated_cost_usd': 0.000124, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 0, 'prompt_complexity_score': 10, 'output_readability_score': 78, 'hallucination_score': 0.962, 'repetition_score': 0.77, 'sentiment_score': 0.114, 'response_variation_score': 0.51, 'toxicity_score': 0.119, 'model_version': 'v2.0.4', 'num_edits_required': 4}
# {'topic': 'financial modeling', 'topic_category': 'Finance', 'user_prompt': 'How do I create a discounted cash flow model?', 'mock_response': 'Project future cash flows, estimate discount rate, and calculate present value for valuation.', 'trace_id': '78d8d323-7828-5677-8228-ef05865a4e29', 'model': 'gpt-4.1', 'event_type': 'llm_generation', 'embedding_x': 0.41497837048501046, 'embedding_y': 0.79042997043776, 'generation_timestamp': 1764960376.9002483, 'input_tokens': 65, 'output_tokens': 123, 'total_tokens': 188, 'latency_sec': 0.625, 'estimated_cost_usd': 0.000111, 'num_sentences': 2, 'num_words': 13, 'num_special_tokens': 0, 'prompt_complexity_score': 8, 'output_readability_score': 79, 'hallucination_score': 0.433, 'repetition_score': 0.992, 'sentiment_score': -0.654, 'response_variation_score': 0.667, 'toxicity_score': 0.556, 'model_version': 'v2.9.1', 'num_edits_required': 4}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 130
#     127                 time.sleep(0.001)
#     129 # Start streaming
# --> 130 stream_to_kafka()
#
# Cell In[3], line 127, in stream_to_kafka()
#     124 print(record)
#     126 # Control speed
# --> 127 time.sleep(0.001)
#
# KeyboardInterrupt:
