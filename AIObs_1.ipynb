# %%
"""
Offline synthetic dataset generator for LLM observability visual demos.
- No expected_output column
- Includes categorical descriptors
- Multiple realistic model names
- Fully offline
"""

import time
import random
import pandas as pd
from tqdm import tqdm

NUM_EXAMPLES = 50
MODELS = [
    "gpt-4.1",
    "gpt-4o-mini",
    "gpt-3.5-turbo",
    "llama2-13b",
    "mistral-7b-instruct"
]

TOPICS = [
    "email summarization",
    "customer support",
    "math word problems",
    "travel planning",
    "coding assistance",
    "creative writing",
]

# Categorical descriptors
RESPONSE_QUALITY = ["Good", "Average", "Poor"]
RESPONSE_TYPE = ["Informative", "Creative", "Actionable"]
TOPIC_CATEGORY = {
    "email summarization": "Communication",
    "customer support": "Support",
    "math word problems": "Education",
    "travel planning": "Leisure",
    "coding assistance": "Programming",
    "creative writing": "Art",
}

LATENCY_RANGE = (0.1, 1.5)
INPUT_TOKENS_RANGE = (10, 80)
OUTPUT_TOKENS_RANGE = (30, 200)
READABILITY_RANGE = (30, 90)
COMPLEXITY_RANGE = (1, 10)

def generate_mock_prompt(topic):
    templates = [
        f"Please provide a detailed {topic} example.",
        f"I need help with {topic}, can you assist?",
        f"Generate a {topic} scenario for testing purposes.",
        f"Write a {topic} sample that covers edge cases.",
        f"Create a realistic {topic} request."
    ]
    return random.choice(templates)

def moc

df.to_csv(r"C:\Users\mikha\OneDrive\Documents\Demos\AI Observability\test.csv")
# Out:
#   Cell In[13], line 60
#     def moc
#            ^
# SyntaxError: expected '('
