# %%
import pandas as pd
from row64tools import ramdb
import numpy as np

# %%
localfile = r"C:\Users\mikha\OneDrive\Documents\Demos\Retail\WM_Synth_Sales_02_skew.csv"

df = pd.read_csv(localfile)
df_l = df.sample(n=1000000, random_state=33)
# df_l.to_csv(r"C:\Users\mikha\OneDrive\Documents\Demos\Retail\Retail_sales_subset.csv")
ramdb.save_from_df(df_l, r"C:\Users\mikha\OneDrive\Documents\Demos\Retail\Retail_Sales.ramdb")

# %%
df_l.to_csv(r"C:\Users\mikha\OneDrive\Documents\Demos\Retail\Retail_sales_subset.csv")
